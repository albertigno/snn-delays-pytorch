# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_excel('./results_shd_soa.xls', sheet_name='D-SNN')
df_rsnn = pd.read_excel('./results_shd_soa.xls', sheet_name='R-SNN')
style = "whitegrid"
figsize = (7,5)

# %%
df_rsnn
# Out:
#     hidden      type  params    acc  spk_neuron  spk_time  avg_spk
# 0      128       LIF  141312  81.80      21.750  22.27200  0.08700
# 1       64       LIF   58368  79.50      35.000  17.92000  0.14000
# 2       48       LIF   41472  79.40      42.500  16.32000  0.17000
# 3       32       LIF   26112  76.24      57.500  14.72000  0.23000
# 4      128  ALIF_old  141312  90.72      27.575  28.23680  0.11030
# 5       64  ALIF_old   58368  83.13      38.825  19.87840  0.15530
# 6       48  ALIF_old   41472  82.72      40.220  15.44448  0.16088
# 7       32  ALIF_old   26112  77.62      45.125  11.55200  0.18050
# 8      128      ALIF  141312  90.72      27.575  28.23680  0.11030
# 9      112      ALIF  118272  86.78      32.000  28.67200  0.12800
# 10      96      ALIF   96768  82.90      33.075  25.40160  0.13230
# 11      80      ALIF   76800  83.88      35.000  22.40000  0.14000
# 12      64      ALIF   58368  85.04      40.525  20.74880  0.16210
# ...

# %%
df
# Out:
#     hidden  stride  pruning   params  prev_acc    acc  spk_neuron  spk_time  \
# 0       32       3       50   105600     88.33  88.33       22.95   5.87520
# 1       32       3        1    24064     15.13  44.48       17.04   4.36224
# 2       32       3        5    30720     44.28  74.41       18.61   4.76416
# 3       32       3       10    39040     63.52  83.15       18.88   4.83328
# 4       32       3       15    47360     71.09  83.88       20.19   5.16864
# 5       32       3       20    55680     78.02  86.37       22.04   5.64224
# 6       32       6       25    64000     86.81  86.81       30.18   7.72608
# 7       32       6        1    24064     18.06  59.08       20.07   5.13792
# 8       32       6        5    30720     59.03  83.74       24.83   6.35648
# 9       32       6       10    39040     77.58  85.49       29.93   7.66208
# 10      32       6       15    47360     82.91  85.64       32.56   8.33536
# ...

# %%
df_np = pd.concat([df[df['pruning']==50],  df[df['pruning']==25] ])

# %%
df_np
# Out:
#     hidden  stride  pruning   params  prev_acc    acc  spk_neuron  spk_time  \
# 0       32       3       50   105600     88.33  88.33       22.95   5.87520
# 12      48       3       50   196800     90.08  90.08       16.25   6.24000
# 24      64       3       50   313600     89.84  89.84       13.24   6.77888
# 36     128       3       50  1036800     86.71  86.71        6.36   6.51264
# 6       32       6       25    64000     86.81  86.81       30.18   7.72608
# 18      48       6       25   115200     90.52  90.52       20.70   7.94880
# 30      64       6       25   179200     89.01  89.01       17.71   9.06752
# 42     128       6       25   563200     89.45  89.45        9.35   9.57440
#
#     spk1_neuron
# 0           NaN
# 12          NaN
# 24          NaN
# 36          NaN
# 6           NaN
# 18          NaN
# 30          NaN
# 42          NaN

# %%
df_p = df[(df['pruning']!=50) & (df['pruning']!=25)]

# %%
df_p
# Out:
#     hidden  stride  pruning  params  prev_acc    acc  spk_neuron  spk_time  \
# 1       32       3        1   24064     15.13  44.48       17.04   4.36224
# 2       32       3        5   30720     44.28  74.41       18.61   4.76416
# 3       32       3       10   39040     63.52  83.15       18.88   4.83328
# 4       32       3       15   47360     71.09  83.88       20.19   5.16864
# 5       32       3       20   55680     78.02  86.37       22.04   5.64224
# 7       32       6        1   24064     18.06  59.08       20.07   5.13792
# 8       32       6        5   30720     59.03  83.74       24.83   6.35648
# 9       32       6       10   39040     77.58  85.49       29.93   7.66208
# 10      32       6       15   47360     82.91  85.64       32.56   8.33536
# 11      32       6       20   55680     86.18  86.03       33.35   8.53760
# 13      48       3        1   36864     14.16  49.46       20.26   7.77984
# ...

# %%
df_lif = df_rsnn[df_rsnn['type']=='LIF']
df_alif = df_rsnn[df_rsnn['type']=='ALIF']

# %% [markdown]
# #### Pruning vs No Pruning

# %%
palette = sns.color_palette("crest",5)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)

sns.set_style(style)
g=sns.scatterplot(data = df_alif, x="params", y="acc", color='orange', label='rsnn (ALIF)', legend=False)
sns.scatterplot(data = df_lif, x="params", y="acc", color='red', label='rsnn (LIF)', legend=False)
sns.scatterplot(data = df_p, x="params", y="acc",hue='pruning', palette= palette, legend=False)
sns.scatterplot(data = df_np, x="params", y="acc", color='k', label='no pruning', legend=False)
plt.xlabel('number of synaptic parameters (millions)')
xlabels = [x for x in g.get_xticks()/1000000]
g.set_xticklabels(xlabels)

plt.xlim(0.1,600000)
plt.subplot(1,2,2)
sns.scatterplot(data = df_alif, x="spk_time", y="acc", color='orange', label='rsnn (ALIF)')
sns.scatterplot(data = df_lif, x="spk_time", y="acc", color='red', label='rsnn (LIF)')
sns.scatterplot(data = df_p, x="spk_time", y="acc",hue='pruning', palette= palette)

sns.scatterplot(data = df_np, x="spk_time", y="acc", color='k', label='no pruning')
plt.xlabel('spikes per timestep')
plt.savefig('shd_results.pdf', dpi=200)
plt.xlim(3,26)
#plt.savefig('shd_pruning_acc.pdf', dpi=200)
# Out:
# C:\Users\saucedo\anaconda3\envs\deeplearnig\lib\site-packages\ipykernel_launcher.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   del sys.path[0]
# (3.0, 26.0)

# %%
palette = sns.color_palette("crest",5)

plt.figure(figsize=(5,5))
sns.set_style(style)

# %%
palette = sns.color_palette("crest",5)

plt.figure(figsize=(5,5))
sns.set_style(style)

sns.scatterplot(data = df_alif, x="spk_time", y="acc", color='orange', label='rsnn (ALIF)')
sns.scatterplot(data = df_lif, x="spk_time", y="acc", color='red', label='rsnn (LIF)')
sns.scatterplot(data = df_p, x="spk_time", y="acc",hue='pruning', palette= palette)

sns.scatterplot(data = df_np, x="spk_time", y="acc", color='k', label='no pruning')
plt.xlabel('spikes per timestep')
plt.savefig('shd_pruning_spk.pdf', dpi=200)

# %%
plt.figure(figsize=(20,10))
sns.set_theme()
sns.scatterplot(data = df, x="params", y="acc", hue='hidden', palette=['g', 'b', 'r', 'y'])
plt.scatter([141312], [87.5], color = 'k')
plt.annotate('ALIF-128', (141312+5000, 87))
plt.scatter([50176], [82.58], color = 'k')
plt.annotate('ALIF-64', (50176+5000, 82))
plt.scatter([36864], [79.18], color = 'k')
plt.annotate('ALIF-48', (36864+5000, 78))
plt.scatter([24064], [79.41], color = 'k')
plt.annotate('ALIF-32', (24064+5000, 80))
plt.xlim(0,600000)
# Out:
# (0.0, 600000.0)

# %%
plt.figure(figsize=(20,10))
sns.set_theme()
sns.scatterplot(data = df_np, x="params", y="acc", hue='hidden', palette=['g', 'b', 'r', 'y'])
plt.scatter([141312], [87.5], color = 'k')
plt.annotate('ALIF-128', (141312+5000, 87))
plt.scatter([50176], [82.58], color = 'k')
plt.annotate('ALIF-64', (50176+5000, 82))
plt.scatter([36864], [79.18], color = 'k')
plt.annotate('ALIF-48', (36864+5000, 78))
plt.scatter([24064], [79.41], color = 'k')
plt.annotate('ALIF-32', (24064+5000, 80))
plt.xlim(0,600000)
# Out:
# (0.0, 600000.0)

# %%
plt.figure(figsize=(20,10))
sns.set_theme()
sns.scatterplot(data = df, x="params", y="acc",color='b')
sns.scatterplot(data = df_lif, x="params", y="acc", color='orange')
sns.scatterplot(data = df_alif, x="params", y="acc", color='r')
plt.xlim(0,200000)
# Out:
# (0.0, 200000.0)

# %%
plt.figure(figsize=(20,10))
sns.set_theme()
sns.scatterplot(data = df_np, x="params", y="acc",color='b')
sns.scatterplot(data = df_lif, x="params", y="acc", color='orange')
sns.scatterplot(data = df_alif, x="params", y="acc", color='r')
plt.xlim(0,200000)
# Out:
# (0.0, 200000.0)

# %%
plt.figure(figsize=(20,10))
sns.set_theme()
sns.scatterplot(data = df, x="spk_time", y="acc",color='b')
sns.scatterplot(data = df_lif, x="spk_time", y="acc", color='orange')
sns.scatterplot(data = df_alif, x="spk_time", y="acc", color='r')
#plt.xlim(0,200000)
# Out:
# <AxesSubplot:xlabel='spk_time', ylabel='acc'>

# %%
plt.figure(figsize=(20,10))
sns.set_theme()
sns.scatterplot(data = df_np, x="spk_time", y="acc",color='b')
sns.scatterplot(data = df_lif, x="spk_time", y="acc", color='orange')
sns.scatterplot(data = df_alif, x="spk_time", y="acc", color='r')
#plt.xlim(0,200000)
# Out:
# <AxesSubplot:xlabel='spk_time', ylabel='acc'>

# %%
plt.figure(figsize=(15,10))
sns.set_theme()
sns.scatterplot(data = df, x="params", y="acc", hue='hidden', palette=['g', 'b', 'r', 'y'])
plt.scatter([141312], [87.5], color = 'k')
plt.annotate('RSNN-ALIF-128', (141312+5000, 87))
plt.scatter([50176], [82.58], color = 'k')
plt.annotate('RSNN-ALIF-64', (50176+5000, 82))
plt.scatter([36864], [79.18], color = 'k')
plt.annotate('RSNN-ALIF-48', (36864+5000, 78))
plt.scatter([36864], [48.6], color = 'magenta')
plt.annotate('FFW-48', (36864+5000, 48))
#plt.scatter([24064], [79.41], color = 'k')
#plt.annotate('ALIF-32', (24064+5000, 80))
plt.xlim(0,200000)
# Out:
# (0.0, 200000.0)

# %%
plt.figure(figsize=(20,10))
sns.set_theme()
sns.scatterplot(data = df, x="params", y="acc", hue='stride', palette=['g', 'r'])
plt.scatter([141312], [87.5], color = 'k')
plt.annotate('ALIF-128', (141312+5000, 87))
plt.scatter([50176], [82.58], color = 'k')
plt.annotate('ALIF-64', (50176+5000, 82))
plt.scatter([36864], [79.18], color = 'k')
plt.annotate('ALIF-48', (36864+5000, 78))
plt.scatter([24064], [79.41], color = 'k')
plt.annotate('ALIF-32', (24064+5000, 80))
plt.xlim(0,600000)
# Out:
# (0.0, 600000.0)

# %%
plt.figure(figsize=(20,10))
sns.set_theme()
sns.scatterplot(data = df, x="params", y="acc", hue='pruning', palette=['g', 'b', 'r', 'y', 'orange', 'cyan', 'magenta'])
plt.scatter([141312], [87.5], color = 'k')
plt.annotate('ALIF-128', (141312+5000, 87))
plt.scatter([50176], [82.58], color = 'k')
plt.annotate('ALIF-64', (50176+5000, 82))
plt.scatter([36864], [79.18], color = 'k')
plt.annotate('ALIF-48', (36864+5000, 78))
plt.scatter([24064], [79.41], color = 'k')
plt.annotate('ALIF-32', (24064+5000, 80))
plt.xlim(0,200000)
# Out:
# (0.0, 200000.0)
