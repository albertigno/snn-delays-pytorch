# %%
#from my_snn.rsnn import RSNN, RSNN_2l, RSNN_2l_ALIF
from my_snn.rsnn_delays import RSNN_d_d, RSNN_d_i, RSNN_d_all
from my_snn.tonic_dataloader import DatasetLoader
from my_snn.utils import train, training_plots, ModelLoader
import torch
device = "cuda:0"

import matplotlib.pyplot as  plt

time_window = 250
batch_size = 256
dataset = 'shd'

DL = DatasetLoader(dataset=dataset, caching='disk', num_workers=0, batch_size=batch_size, time_window=time_window)
test_loader, train_loader = DL.get_dataloaders()

ckpt_dir = 'shd_soa_tests'

data = test_loader, train_loader

dropout = 0.2

import numpy as np
def test_fn(snn, ckpt_dir, test_loader, ma, epoch):
    if (epoch + 1) % 5 == 0:
        snn.test(test_loader, dropout = dropout)
        last_acc = np.array(snn.acc)[-1,1]
        max_acc = np.max(np.array(snn.acc)[:,1])
        if last_acc == max_acc:
            print(f'saving max acc: {max_acc}')
            snn.save_model(snn.modelname+'_'+ ''.join(str(np.array(snn.acc)[-1,1]).split('.')) , ckpt_dir)

# %%
snn = ModelLoader('shd250_64x2_d_150_3_fs_8984375', ckpt_dir, batch_size, device)
snn.test(test_loader, dropout = dropout)
# Out:
# delays: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# instance of <class 'my_snn.rsnn_delays.RSNN_d_d'> loaded sucessfully
# Test Loss: 0.570182170186724
# Avg spk_count per neuron for all 250 timesteps 11.998584747314453
# Test Accuracy of the model on the test samples: 89.941

# %%
k = 1
snn_pooled = ModelLoader('shd250_64x2_d_150_3_fs_8984375', ckpt_dir, batch_size, 'cpu')
snn_pooled.pool_delays('ho', k=k)
snn_pooled.test(test_loader, dropout = dropout)
# Out:
# delays: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# instance of <class 'my_snn.rsnn_delays.RSNN_d_d'> loaded sucessfully
# Test Loss: 3.3442819118499756
# Avg spk_count per neuron for all 250 timesteps 6.714752197265625
# Test Accuracy of the model on the test samples: 24.268

# %%
k = 5
snn_pooled = ModelLoader('shd250_64x2_d_150_3_fs_8984375', ckpt_dir, batch_size, 'cpu')
snn_pooled.pool_delays('ho', k=k)
snn_pooled.test(test_loader, dropout = dropout)
# Out:
# delays: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# instance of <class 'my_snn.rsnn_delays.RSNN_d_d'> loaded sucessfully
# Test Loss: 2.08895742893219
# Avg spk_count per neuron for all 250 timesteps 8.707916259765625
# Test Accuracy of the model on the test samples: 52.490

# %%
k = 10
snn_pooled = ModelLoader('shd250_64x2_d_150_3_fs_8984375', ckpt_dir, batch_size, 'cpu')
snn_pooled.pool_delays('ho', k=k)
snn_pooled.test(test_loader, dropout = dropout)
# Out:
# delays: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# instance of <class 'my_snn.rsnn_delays.RSNN_d_d'> loaded sucessfully
# Test Loss: 1.0821070671081543
# Avg spk_count per neuron for all 250 timesteps 10.265254974365234
# Test Accuracy of the model on the test samples: 70.264

# %%
k = 1
snn_pooled = ModelLoader('shd250_64x2_d_150_3_fs_8984375', ckpt_dir, batch_size, device)
snn_pooled.pool_delays('ho', k=k)
snn_pooled.test(test_loader, dropout = dropout)

snn_pooled.modelname = f'shd250_64x2_d_150_3_fs_pooled_{k}'
train(snn_pooled, data, 1e-3, 50, dropout=0.2, lr_scale=(5.0, 2.0), ckpt_dir=ckpt_dir, test_fn=test_fn, scheduler=(10, 0.95))
torch.cuda.empty_cache()
# Out:
# delays: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# instance of <class 'my_snn.rsnn_delays.RSNN_d_d'> loaded sucessfully
# Test Loss: 3.3433974470411028
# Avg spk_count per neuron for all 250 timesteps 6.727081298828125
# Test Accuracy of the model on the test samples: 24.170
# RSNN_d_d(
#   (criterion): CrossEntropyLoss()
#   (f0_i): Linear(in_features=700, out_features=64, bias=False)
#   (f1_f2): Linear(in_features=3200, out_features=64, bias=False)
#   (f2_o): Linear(in_features=3200, out_features=20, bias=False)
# )
# Total params: 313600
# Total mult-adds (M): 78.4
# training shd250_64x2_d_150_3_fs_pooled_1 for 50 epochs...
# Epoch [1/50]
# Step [10/31], Loss: 28.64904
# Step [20/31], Loss: 27.78502
# Step [30/31], Loss: 27.05833
# Time elasped: 63.42392635345459
# Epoch [2/50]
# Step [10/31], Loss: 26.33533
# Step [20/31], Loss: 26.11957
# Step [30/31], Loss: 25.87941
# Time elasped: 63.19545245170593
# Epoch [3/50]
# Step [10/31], Loss: 25.56727
# Step [20/31], Loss: 25.38384
# Step [30/31], Loss: 25.09656
# Time elasped: 63.23952507972717
# Epoch [4/50]
# Step [10/31], Loss: 24.79818
# Step [20/31], Loss: 24.63605
# Step [30/31], Loss: 24.59852
# Time elasped: 63.388465881347656
# Epoch [5/50]
# Step [10/31], Loss: 24.05435
# Step [20/31], Loss: 24.11592
# Step [30/31], Loss: 23.71686
# Time elasped: 62.91826844215393
# Test Loss: 2.6641512598310197
# Avg spk_count per neuron for all 250 timesteps 17.585811614990234
# Test Accuracy of the model on the test samples: 33.838
# saving max acc: 89.84375
# Epoch [6/50]
# Step [10/31], Loss: 23.39196
# Step [20/31], Loss: 23.11616
# Step [30/31], Loss: 22.99600
# Time elasped: 63.51059055328369
# Epoch [7/50]
# Step [10/31], Loss: 22.61358
# Step [20/31], Loss: 22.42151
# Step [30/31], Loss: 22.17656
# Time elasped: 63.34882211685181
# Epoch [8/50]
# Step [10/31], Loss: 21.75602
# Step [20/31], Loss: 21.71227
# Step [30/31], Loss: 21.21955
# Time elasped: 63.75348258018494
# Epoch [9/50]
# Step [10/31], Loss: 20.81605
# Step [20/31], Loss: 20.70170
# Step [30/31], Loss: 20.51465
# Time elasped: 63.472878217697144
# Epoch [10/50]
# Step [10/31], Loss: 19.93422
# Step [20/31], Loss: 19.74770
# Step [30/31], Loss: 19.70679
# Time elasped: 63.28552198410034
# Test Loss: 2.235567126955305
# Avg spk_count per neuron for all 250 timesteps 18.346969604492188
# Test Accuracy of the model on the test samples: 39.160
# saving max acc: 89.84375
# Epoch [11/50]
# Step [10/31], Loss: 19.14438
# Step [20/31], Loss: 18.99093
# Step [30/31], Loss: 18.62819
# Time elasped: 63.491482734680176
# Epoch [12/50]
# Step [10/31], Loss: 18.50157
# Step [20/31], Loss: 17.94825
# Step [30/31], Loss: 17.63644
# Time elasped: 63.204827070236206
# Epoch [13/50]
# Step [10/31], Loss: 17.47190
# Step [20/31], Loss: 16.92102
# Step [30/31], Loss: 17.04668
# Time elasped: 63.204238176345825
# Epoch [14/50]
# Step [10/31], Loss: 16.23639
# Step [20/31], Loss: 16.36278
# Step [30/31], Loss: 16.43655
# Time elasped: 63.1901798248291
# Epoch [15/50]
# Step [10/31], Loss: 15.71118
# Step [20/31], Loss: 15.69518
# Step [30/31], Loss: 15.43698
# Time elasped: 63.32031059265137
# Step [20/31], Loss: 7.87753
# Step [30/31], Loss: 7.62973
# Time elasped: 65.93269991874695
# Epoch [48/50]
# Step [10/31], Loss: 7.79295
# Step [20/31], Loss: 7.63719
# Step [30/31], Loss: 7.73965
# Time elasped: 65.22988176345825
# Epoch [49/50]
# Step [10/31], Loss: 7.62131
# Step [20/31], Loss: 7.35726
# Step [30/31], Loss: 7.71311
# Time elasped: 65.09309411048889
# Epoch [50/50]
# Step [10/31], Loss: 7.38114
# Step [20/31], Loss: 7.55156
# Step [30/31], Loss: 7.57169
# Time elasped: 64.62905216217041
# Test Loss: 1.8527416672025407
# Avg spk_count per neuron for all 250 timesteps 17.225719451904297
# Test Accuracy of the model on the test samples: 53.906

# %%
k = 5
snn_pooled = ModelLoader('shd250_64x2_d_150_3_fs_8984375', ckpt_dir, batch_size, device)
snn_pooled.pool_delays('ho', k=k, freeze=False)
snn_pooled.test(test_loader, dropout = dropout)

snn_pooled.modelname = f'shd250_64x2_d_150_3_fs_pooled_{k}'
train(snn_pooled, data, 1e-3, 50, dropout=0.2, lr_scale=(5.0, 2.0), ckpt_dir=ckpt_dir, test_fn=test_fn, scheduler=(10, 0.95))
torch.cuda.empty_cache()
# Out:
# delays: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# instance of <class 'my_snn.rsnn_delays.RSNN_d_d'> loaded sucessfully
# Test Loss: 2.0819065400532315
# Avg spk_count per neuron for all 250 timesteps 8.720348358154297
# Test Accuracy of the model on the test samples: 53.955
# RSNN_d_d(
#   (criterion): CrossEntropyLoss()
#   (f0_i): Linear(in_features=700, out_features=64, bias=False)
#   (f1_f2): Linear(in_features=3200, out_features=64, bias=False)
#   (f2_o): Linear(in_features=3200, out_features=20, bias=False)
# )
# Total params: 313600
# Total mult-adds (M): 78.4
# training shd250_64x2_d_150_3_fs_pooled_5 for 50 epochs...
# Epoch [1/50]
# Step [10/31], Loss: 15.18680
# Step [20/31], Loss: 13.29611
# Step [30/31], Loss: 12.41029
# Time elasped: 64.63624596595764
# Epoch [2/50]
# Step [10/31], Loss: 11.80429
# Step [20/31], Loss: 11.17444
# Step [30/31], Loss: 10.91834
# Time elasped: 64.48237657546997
# Epoch [3/50]
# Step [10/31], Loss: 10.62073
# Step [20/31], Loss: 9.88631
# Step [30/31], Loss: 9.97961
# Time elasped: 64.46804738044739
# Epoch [4/50]
# Step [10/31], Loss: 9.47159
# Step [20/31], Loss: 9.48986
# Step [30/31], Loss: 9.18194
# Time elasped: 64.90624380111694
# Epoch [5/50]
# Step [10/31], Loss: 8.70687
# Step [20/31], Loss: 8.33260
# Step [30/31], Loss: 8.56791
# Time elasped: 64.57290124893188
# Test Loss: 1.1564889550209045
# Avg spk_count per neuron for all 250 timesteps 10.535125732421875
# Test Accuracy of the model on the test samples: 73.340
# saving max acc: 89.84375
# Epoch [6/50]
# Step [10/31], Loss: 8.02450
# Step [20/31], Loss: 7.92098
# Step [30/31], Loss: 7.38043
# Time elasped: 64.79250001907349
# Epoch [7/50]
# Step [10/31], Loss: 7.34647
# Step [20/31], Loss: 7.28916
# Step [30/31], Loss: 7.07548
# Time elasped: 64.81221842765808
# Epoch [8/50]
# Step [10/31], Loss: 1.51779
# Step [20/31], Loss: 1.62565
# Step [30/31], Loss: 1.72786
# Time elasped: 64.29923224449158
# Test Loss: 1.1151070935385567
# Avg spk_count per neuron for all 250 timesteps 9.27630615234375
# Test Accuracy of the model on the test samples: 72.900
# Epoch [41/50]
# Step [10/31], Loss: 1.80029
# Step [20/31], Loss: 1.48107
# Step [30/31], Loss: 1.68119
# Time elasped: 64.04043912887573
# Epoch [42/50]
# Step [10/31], Loss: 1.64011
# Step [20/31], Loss: 1.77212
# Step [30/31], Loss: 1.57340
# Time elasped: 64.085533618927
# Epoch [43/50]
# Step [10/31], Loss: 1.65414
# Step [20/31], Loss: 1.49173
# Step [30/31], Loss: 1.59193
# Time elasped: 64.1203966140747
# Epoch [44/50]
# Step [10/31], Loss: 1.45196
# Step [20/31], Loss: 1.71157
# Step [30/31], Loss: 1.59290
# Time elasped: 64.23467564582825
# Epoch [45/50]
# Step [10/31], Loss: 1.46617
# Step [20/31], Loss: 1.69591
# Step [30/31], Loss: 1.60390
# Time elasped: 64.37581515312195
# Test Loss: 1.158044193472181
# Avg spk_count per neuron for all 250 timesteps 9.051822662353516
# Test Accuracy of the model on the test samples: 72.754
# Epoch [46/50]
# Step [10/31], Loss: 1.61390
# Step [20/31], Loss: 1.43526
# Step [30/31], Loss: 1.30373
# Time elasped: 64.33185338973999
# Epoch [47/50]
# Step [10/31], Loss: 1.47361
# Step [20/31], Loss: 1.74238
# Step [30/31], Loss: 1.59568
# Time elasped: 64.13711380958557
# Epoch [48/50]
# Step [10/31], Loss: 1.63372
# Step [20/31], Loss: 1.40484
# Step [30/31], Loss: 1.51534
# Time elasped: 64.10698366165161
# Epoch [49/50]
# Step [10/31], Loss: 1.54305
# Step [20/31], Loss: 1.58364
# Step [30/31], Loss: 1.57431
# Time elasped: 64.1857545375824
# Epoch [50/50]
# Step [10/31], Loss: 1.38854
# Step [20/31], Loss: 1.35228
# Step [30/31], Loss: 1.56987
# Time elasped: 64.06444120407104
# Test Loss: 1.1978743502071925
# Avg spk_count per neuron for all 250 timesteps 9.225738525390625
# Test Accuracy of the model on the test samples: 72.168

# %%
k = 10
snn_pooled = ModelLoader('shd250_64x2_d_150_3_fs_8984375', ckpt_dir, batch_size, device)
snn_pooled.pool_delays('ho', k=k, freeze=False)
snn_pooled.test(test_loader, dropout = dropout)

snn_pooled.modelname = f'shd250_64x2_d_150_3_fs_pooled_{k}'
train(snn_pooled, data, 1e-3, 50, dropout=0.2, lr_scale=(5.0, 2.0), ckpt_dir=ckpt_dir, test_fn=test_fn, scheduler=(10, 0.95))
torch.cuda.empty_cache()
# Out:
# delays: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# instance of <class 'my_snn.rsnn_delays.RSNN_d_d'> loaded sucessfully
# Test Loss: 1.0963101642472404
# Avg spk_count per neuron for all 250 timesteps 10.264961242675781
# Test Accuracy of the model on the test samples: 69.434
# RSNN_d_d(
#   (criterion): CrossEntropyLoss()
#   (f0_i): Linear(in_features=700, out_features=64, bias=False)
#   (f1_f2): Linear(in_features=3200, out_features=64, bias=False)
#   (f2_o): Linear(in_features=3200, out_features=20, bias=False)
# )
# Total params: 313600
# Step [30/31], Loss: 0.27081
# Time elasped: 63.72568941116333
# Epoch [49/50]
# Step [10/31], Loss: 0.27741
# Step [20/31], Loss: 0.25747
# Step [30/31], Loss: 0.25463
# Time elasped: 63.6099169254303
# Epoch [50/50]
# Step [10/31], Loss: 0.24635
# Step [20/31], Loss: 0.28523
# Step [30/31], Loss: 0.24607
# Time elasped: 63.61110234260559
# Test Loss: 1.038680034024375
# Avg spk_count per neuron for all 250 timesteps 9.195228576660156
# Test Accuracy of the model on the test samples: 80.225

# %%
torch.cuda.empty_cache()

# %%
dropout = 0.2

import numpy as np
def test_fn(snn, ckpt_dir, test_loader, ma, epoch):
    if (epoch + 1) % 5 == 0:
        k = 50-epoch
        print(f'pruninng to {k} delays')
        snn.pool_delays('ho', k=k)
        snn.test(test_loader, dropout = dropout)
        last_acc = np.array(snn.acc)[-1,1]
        max_acc = np.max(np.array(snn.acc)[:,1])
        if last_acc == max_acc:
            print(f'saving max acc: {max_acc}')
            snn.save_model(snn.modelname+'_'+ ''.join(str(np.array(snn.acc)[-1,1]).split('.')) , ckpt_dir)
            
snn_pooled = ModelLoader('shd250_64x2_d_150_3_fs_8984375', ckpt_dir, batch_size, device)
snn_pooled.test(test_loader, dropout = dropout)

snn_pooled.modelname = f'shd250_64x2_d_150_3_fs_pooled_k'
train(snn_pooled, data, 1e-3, 50, dropout=0.2, lr_scale=(5.0, 2.0), ckpt_dir=ckpt_dir, test_fn=test_fn, scheduler=(10, 0.95))
torch.cuda.empty_cache()
# Out:
# delays: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# instance of <class 'my_snn.rsnn_delays.RSNN_d_d'> loaded sucessfully
# Test Loss: 0.5540129201752799
# Avg spk_count per neuron for all 250 timesteps 12.014633178710938
# Test Accuracy of the model on the test samples: 89.453
# RSNN_d_d(
#   (criterion): CrossEntropyLoss()
#   (f0_i): Linear(in_features=700, out_features=64, bias=False)
#   (f1_f2): Linear(in_features=3200, out_features=64, bias=False)
#   (f2_o): Linear(in_features=3200, out_features=20, bias=False)
# )
# Total params: 313600
# Total mult-adds (M): 78.4
# training shd250_64x2_d_150_3_fs_pooled_k for 50 epochs...
# Epoch [1/50]
# Step [10/31], Loss: 2.63532
# Step [20/31], Loss: 1.11510
# Step [30/31], Loss: 0.49893
# Time elasped: 65.71446347236633
# Epoch [2/50]
# Step [10/31], Loss: 0.14331
# Step [20/31], Loss: 0.19175
# Step [30/31], Loss: 0.17286
# Time elasped: 64.34388256072998
# Epoch [3/50]
# Step [10/31], Loss: 0.10833
# Step [20/31], Loss: 0.13647
# Step [30/31], Loss: 0.10431
# Time elasped: 64.19152879714966
# Epoch [4/50]
# Step [10/31], Loss: 0.09677
# Step [20/31], Loss: 0.08604
# Step [30/31], Loss: 0.21839
# Time elasped: 64.71590375900269
# Epoch [5/50]
# Step [10/31], Loss: 0.11305
# Step [20/31], Loss: 0.09139
# Step [30/31], Loss: 0.32664
# Time elasped: 64.53680491447449
# pruninng to 46 delays
# Test Loss: 0.9247443761144366
# Avg spk_count per neuron for all 250 timesteps 10.938404083251953
# Test Accuracy of the model on the test samples: 83.447
# saving max acc: 89.84375
# Epoch [6/50]
# Step [10/31], Loss: 0.59617
# Step [20/31], Loss: 0.61258
# Step [30/31], Loss: 0.60041
# Time elasped: 63.57281255722046
# Epoch [38/50]
# Step [10/31], Loss: 0.53731
# Step [20/31], Loss: 0.54002
# Step [30/31], Loss: 0.43035
# Time elasped: 63.46760368347168
# Epoch [39/50]
# Step [10/31], Loss: 0.42905
# Step [20/31], Loss: 0.44733
# Step [30/31], Loss: 0.43952
# Time elasped: 63.18885636329651
# Epoch [40/50]
# Step [10/31], Loss: 0.39742
# Step [20/31], Loss: 0.37824
# Step [30/31], Loss: 0.38115
# Time elasped: 62.93477177619934
# pruninng to 11 delays
# Test Loss: 0.8048206482614789
# Avg spk_count per neuron for all 250 timesteps 8.62808609008789
# Test Accuracy of the model on the test samples: 78.516
# Epoch [41/50]
# Step [10/31], Loss: 2.17000
# Step [20/31], Loss: 1.86715
# Step [30/31], Loss: 1.62996
# Time elasped: 64.07442784309387
# Epoch [42/50]
# Step [10/31], Loss: 1.45958
# Step [20/31], Loss: 1.41135
# Step [30/31], Loss: 1.25156
# Time elasped: 64.16123366355896
# Epoch [43/50]
# Step [10/31], Loss: 1.25361
# Step [20/31], Loss: 1.21623
# Step [30/31], Loss: 1.02336
# Time elasped: 63.30357623100281
# Epoch [44/50]
# Step [10/31], Loss: 0.94070
# Step [20/31], Loss: 0.95160
# Step [30/31], Loss: 1.07664
# Time elasped: 63.30219125747681
# Epoch [45/50]
# Step [10/31], Loss: 0.84645
# Step [20/31], Loss: 0.85922
# Step [30/31], Loss: 0.79681
# Time elasped: 63.278260231018066
# pruninng to 6 delays
# Test Loss: 1.3244136742183141
# Avg spk_count per neuron for all 250 timesteps 7.5130157470703125
# Test Accuracy of the model on the test samples: 66.748
# Epoch [46/50]
# Step [10/31], Loss: 7.54210
# Step [20/31], Loss: 6.19417
# Step [30/31], Loss: 5.76758
# Time elasped: 63.407745599746704
# Epoch [47/50]
# Step [10/31], Loss: 4.99577
# Step [20/31], Loss: 4.57183
# Step [30/31], Loss: 4.47302
# Time elasped: 63.37770342826843
# Epoch [48/50]
# Step [10/31], Loss: 4.06901
# Step [20/31], Loss: 3.57915
# Step [30/31], Loss: 3.77686
# Time elasped: 63.460275411605835
# Epoch [49/50]
# Step [10/31], Loss: 3.33474
# Step [20/31], Loss: 3.30600
# Step [30/31], Loss: 3.33972
# Time elasped: 63.37105894088745
# Epoch [50/50]
# Step [10/31], Loss: 3.22388
# Step [20/31], Loss: 2.90062
# Step [30/31], Loss: 2.88727
# Time elasped: 63.167134523391724
# pruninng to 1 delays
# Test Loss: 3.153618403843471
# Avg spk_count per neuron for all 250 timesteps 5.168537139892578
# Test Accuracy of the model on the test samples: 21.973

# %%
snn_pooled.epoch
# Out:
# 6

# %%
k = 15
snn_pooled = ModelLoader('shd250_64x2_d_150_3_fs_8984375', ckpt_dir, batch_size, device)
snn_pooled.pool_delays('ho', k=k, freeze=False)
snn_pooled.test(test_loader, dropout = dropout)

snn_pooled.modelname = f'shd250_64x2_d_150_3_fs_pooled_{k}'
train(snn_pooled, data, 1e-3, 50, dropout=0.2, lr_scale=(5.0, 2.0), ckpt_dir=ckpt_dir, test_fn=test_fn, scheduler=(10, 0.95))
torch.cuda.empty_cache()
# Out:
# delays: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# instance of <class 'my_snn.rsnn_delays.RSNN_d_d'> loaded sucessfully
# Test Loss: 0.6817305556365422
# Avg spk_count per neuron for all 250 timesteps 10.959266662597656
# Test Accuracy of the model on the test samples: 81.201
# RSNN_d_d(
#   (criterion): CrossEntropyLoss()
#   (f0_i): Linear(in_features=700, out_features=64, bias=False)
#   (f1_f2): Linear(in_features=3200, out_features=64, bias=False)
#   (f2_o): Linear(in_features=3200, out_features=20, bias=False)
# )
# Total params: 313600
# Total mult-adds (M): 78.4
# training shd250_64x2_d_150_3_fs_pooled_15 for 50 epochs...
# Epoch [1/50]
# Step [10/31], Loss: 2.40116
# Step [20/31], Loss: 1.90690
# Step [30/31], Loss: 1.87739
# Time elasped: 73.11104083061218
# Epoch [2/50]
# Step [10/31], Loss: 1.39316
# Step [20/31], Loss: 1.35128
# Step [30/31], Loss: 1.44486
# Time elasped: 70.32180714607239
# Epoch [3/50]
# Step [10/31], Loss: 1.14274
# Step [20/31], Loss: 1.15677
# Step [30/31], Loss: 1.05719
# Time elasped: 69.20254015922546
# Epoch [4/50]
# Step [10/31], Loss: 0.94178
# Step [20/31], Loss: 0.88545
# Step [30/31], Loss: 0.89355
# Time elasped: 66.1728036403656
# Epoch [5/50]
# Step [10/31], Loss: 0.83533
# Step [20/31], Loss: 0.76150
# Step [30/31], Loss: 0.80027
# Time elasped: 65.1941921710968
# pruninng to 46 delays
# Test Loss: 0.483345274414335
# Avg spk_count per neuron for all 250 timesteps 10.032764434814453
# Test Accuracy of the model on the test samples: 88.477
# saving max acc: 89.84375
# Epoch [6/50]
# Step [10/31], Loss: 0.74849
# Step [20/31], Loss: 0.69781
# Step [30/31], Loss: 0.74627
# Time elasped: 64.29795598983765
# Epoch [7/50]
# Step [10/31], Loss: 0.56629
# Step [20/31], Loss: 0.55084
# Step [30/31], Loss: 0.60672
# Time elasped: 63.9094033241272
# Epoch [8/50]
# Step [10/31], Loss: 0.56485
# Step [20/31], Loss: 0.45298
# Step [30/31], Loss: 0.46860
# Time elasped: 63.781967878341675
# Epoch [9/50]
# Step [10/31], Loss: 0.44380
# Step [20/31], Loss: 0.38222
# Step [30/31], Loss: 0.49571
# Time elasped: 64.66401100158691
# Epoch [10/50]
# Step [10/31], Loss: 0.51800
# Step [20/31], Loss: 0.46439
# Step [30/31], Loss: 0.39843
# Time elasped: 65.11575770378113
# pruninng to 41 delays
# Test Loss: 0.5397159372057233
# Avg spk_count per neuron for all 250 timesteps 10.628204345703125
# Test Accuracy of the model on the test samples: 86.865
# saving max acc: 89.84375
# Epoch [11/50]
# Step [10/31], Loss: 0.39132
# Step [20/31], Loss: 0.40026
# Step [30/31], Loss: 0.40942
# Time elasped: 65.74886393547058
# Epoch [12/50]
# Step [10/31], Loss: 0.33985
# Step [20/31], Loss: 0.36060
# Step [30/31], Loss: 0.34013
# Time elasped: 65.001779794693
# Epoch [13/50]
# Step [10/31], Loss: 0.27566
# Step [20/31], Loss: 0.33623
# Step [30/31], Loss: 0.32573
# Time elasped: 65.8222188949585
# Epoch [14/50]
# Step [10/31], Loss: 0.34600
# Step [20/31], Loss: 0.26486
# Step [30/31], Loss: 0.32560
# Time elasped: 64.76743960380554
# Epoch [15/50]
# Step [10/31], Loss: 0.27897
# Step [20/31], Loss: 0.23638
# Step [30/31], Loss: 0.27724
# Time elasped: 63.756251096725464
# pruninng to 36 delays
# Test Loss: 0.5621467786175864
# Avg spk_count per neuron for all 250 timesteps 10.325881958007812
# Test Accuracy of the model on the test samples: 86.475
# saving max acc: 89.84375
# Epoch [16/50]
# Step [10/31], Loss: 0.25815
# Step [20/31], Loss: 0.18373
# Step [30/31], Loss: 0.27036
# Time elasped: 64.48595261573792
# Epoch [17/50]
# Step [10/31], Loss: 0.27321
# Step [20/31], Loss: 0.22813
# Step [30/31], Loss: 0.18816
# Time elasped: 64.36872982978821
# Epoch [18/50]
# Step [10/31], Loss: 0.23886
# Step [20/31], Loss: 0.23915
# Step [30/31], Loss: 0.24422
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-481c7e026df3> in <module>
#       5
#       6 snn_pooled.modelname = f'shd250_64x2_d_150_3_fs_pooled_{k}'
# ----> 7 train(snn_pooled, data, 1e-3, 50, dropout=0.2, lr_scale=(5.0, 2.0), ckpt_dir=ckpt_dir, test_fn=test_fn, scheduler=(10, 0.95))
#       8 torch.cuda.empty_cache()
#
# ~\Python\SRNN_tests\my_snn\utils.py in train(snn, data, learning_rate, num_epochs, spkreg, l1_reg, dropout, lr_scale, ckpt_dir, test_fn, scheduler)
#      69         print('Epoch [%d/%d]'  % (epoch + 1, num_epochs))
#      70         start_time = time.time()
# ---> 71         snn.train_step(train_loader, optimizer=optimizer, spkreg=spkreg, l1_reg=l1_reg, dropout=dropout)
#      72         t =  time.time() - start_time
#      73         print('Time elasped:', t)
#
# ~\Python\SRNN_tests\my_snn\abstract_rsnn.py in train_step(self, train_loader, optimizer, spkreg, l1_reg, dropout)
#     137         sr = spkreg/self.win
#     138
# --> 139         for i, (images, labels) in enumerate(train_loader):
#     140             self.zero_grad()
#     141             optimizer.zero_grad()
#
# ~\anaconda3\envs\deeplearnig\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~\anaconda3\envs\deeplearnig\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# ~\anaconda3\envs\deeplearnig\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~\anaconda3\envs\deeplearnig\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~\anaconda3\envs\deeplearnig\lib\site-packages\tonic\cached_dataset.py in __getitem__(self, item)
#     124         file_path = os.path.join(self.cache_path, f"{item}_{copy}.hdf5")
#     125         try:
# --> 126             data, targets = load_from_disk_cache(file_path)
#     127         except (FileNotFoundError, OSError) as _:
#     128             logging.info(
#
# ~\anaconda3\envs\deeplearnig\lib\site-packages\tonic\cached_dataset.py in load_from_disk_cache(file_path)
#     204                     }
#     205                 else:
# --> 206                     data = f[f"{name}/{index}"][()]
#     207                 _list.append(data)
#     208     if len(data_list) == 1:
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~\anaconda3\envs\deeplearnig\lib\site-packages\h5py\_hl\group.py in __getitem__(self, name)
#     262                 raise ValueError("Invalid HDF5 object reference")
#     263         else:
# --> 264             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     265
#     266         otype = h5i.get_type(oid)
#
# ~\anaconda3\envs\deeplearnig\lib\site-packages\h5py\_hl\base.py in _e(self, name, lcpl)
#     112         return dlcpl
#     113
# --> 114     def _e(self, name, lcpl=None):
#     115         """ Encode a name according to the current file settings.
#     116
#
# KeyboardInterrupt:
