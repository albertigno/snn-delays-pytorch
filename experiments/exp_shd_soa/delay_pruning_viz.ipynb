# %%
from my_snn.rsnn_delays import RSNN_d_d, RSNN_d_i, RSNN_d_all
from my_snn.tonic_dataloader import DatasetLoader
from my_snn.utils import train, training_plots, ModelLoader
import torch
device = "cuda:0"

batch_size=256

snn_base = ModelLoader('shd250_32x2_d_150_3_fs_88330078125', 'shd_soa_baselines', batch_size, 'cuda:0')
snn_20 = ModelLoader('shd250_32x2_d_150_3_fs_88330078125_pooled_20_86376953125', 'barridos_shd', batch_size, 'cuda:0')
snn_10 = ModelLoader('shd250_32x2_d_150_3_fs_88330078125_pooled_10_83154296875', 'barridos_shd', batch_size, 'cuda:0')
snn_1 = ModelLoader('shd250_32x2_d_150_3_fs_88330078125_pooled_1_44482421875', 'barridos_shd', batch_size, 'cuda:0')
# Out:
# delays: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# instance of <class 'my_snn.rsnn_delays.RSNN_d_d'> loaded sucessfully
# delays: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# instance of <class 'my_snn.rsnn_delays.RSNN_d_d'> loaded sucessfully
# delays: [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147]
# instance of <class 'my_snn.rsnn_delays.RSNN_d_d'> loaded sucessfully
# ...

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3, ax4) = plt.subplots(figsize=(20, 15), ncols=4)
snn_base.plot(snn_base.f2_o.weight.reshape(20,32,50)[0], mode='matrix', ax=ax1)
snn_base.plot(snn_20.f2_o.weight.reshape(20,32,50)[0], mode='matrix', ax=ax2)
snn_base.plot(snn_10.f2_o.weight.reshape(20,32,50)[0], mode='matrix', ax=ax3)
snn_base.plot(snn_1.f2_o.weight.reshape(20,32,50)[0], mode='matrix', ax=ax4)
ax1.set_title('base (50) delays')
ax2.set_title('20 delays')
ax3.set_title('10 delays')
ax4.set_title('1 delay per synapse')
# Out:
# Text(0.5, 1.0, '1 delay per synapse')
