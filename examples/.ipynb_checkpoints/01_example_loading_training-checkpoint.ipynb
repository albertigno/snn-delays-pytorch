# %% [markdown]
# # Example 1: Loading/training
# In this example I explain:
# - How to configure/load the desired dataset (options are 'tonic' datasets and benchmarks (such as the addition task)).
# - How to configure instantiate an SNN
# - How to train it
# - How to load and test saves models

# %% [markdown]
# ### Prerequisites and environment variables

# %% [markdown]
# Requirements (specific versions recommended but not mandatory):
# - python 3.6
# - pytorch 1.7.1
# - numpy 1.19.5
# - torch-summary 1.4.5
# - matplotlib 3.3.4
# - seaborn 0.11.1
# - scikit-learn 0.24.1
# - scipy 1.5.2
# - h5py 2.10.0
#
# Setting up the snn library:
# - add the parent location of \dsnn to the environment variable PYTHONPATH
# - create a directory with your preferred name, e.g: SNNData and add it to a new environment variable PYTHON_DRIVE_PATH. In this directory, create three empty folders:
#   - checkpoints: here the saved models are stored.
#   - tonic_datasets: here the full datasets from tonic are downloaded
#   - tonic_cache: here the disk cached tonic datasets are stored

# %%
import os

# %%
os.

# %%
import dsnn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-9565c71a0dec> in <module>
# ----> 1 import dsnn
#
# ModuleNotFoundError: No module named 'dsnn'

# %%
import torch
from dsnn.rsnn import RSNN_2l
from dsnn.utils import train, training_plots, ModelLoader
from dsnn.tonic_dataloader import DatasetLoader
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print ('Running on: {}'.format(device))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-778dcb9c7119> in <module>
#       1 import torch
# ----> 2 from dsnn.rsnn import RSNN_2l
#       3 from dsnn.utils import train, training_plots, ModelLoader
#       4 from dsnn.tonic_dataloader import DatasetLoader
#       5 device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#
# ModuleNotFoundError: No module named 'dsnn'

# %% [markdown]
# ### Tonic Dataloader: SHD

# %% [markdown]
# Here I use pre-configured Pytorch dataloaders from [Tonic](https://tonic.readthedocs.io/en/latest/) \
# Available datasets:
# - 'shd': [Spoken Heidelberg Digits](https://zenkelab.org/resources/spiking-heidelberg-datasets-shd/), 700 inputs, 20 classes
# - 'ssc': [Speech Commands](https://zenkelab.org/resources/spiking-heidelberg-datasets-shd/) 700 inputs, 35 classes
# - 'nmnist': [Neuromorphic-MNIST](https://www.garrickorchard.com/datasets/n-mnist) 34x34x2 inputs, 10 classes
# - 'ibmgesture': [DVS Gestures](https://research.ibm.com/interactive/dvsgesture/), 128x128x2 inputs, 11 classes
# - 'ibmgestures32': Downsampled DVS Gestures, 32x32x2 inputs, 11 classes
# - 'smnist': Spiking Sequential MNIST, 99 inputs, 10 classes
#
# Caching options can be either:
# - 'memory': The data goes to GPU Memory, trains faster, limited to availabe GPU memory, use for small models/datasets
# - 'disk': The data is loaded directly from hard drive. Slower, but allows using larger models/datasets.
#
# Other options:
#
# - num_workers: for multithreading on data parallelization (check tonic documentation for more details) \
# Better to keep in 0. But depending on the machine, tuning this number can lead to faster dataloading.
# - batch_size: decide this value wisely, a large batch size (that fits in memory) allows faster training, \
# but has slower convergence (if at all).
# - time_window: sequence lenght, number of time steps/bins, from the 'ToFrame' transform in tonic
#
# What we obtain:
# - data: a tuple (test_loader, train_loader)  used for training, testing the model

# %%
dataset = 'shd' 
time_window = 50
batch_size = 256 # lr=1e-4
DL = DatasetLoader(dataset=dataset, caching='memory', num_workers=0, batch_size=batch_size, time_window=time_window)
data = DL.get_dataloaders()

# %% [markdown]
# ### Network instantiation

# %% [markdown]
# Instantiating a network is simple, just import and instantiate the desired class, with the desired parameters as arguments. \
# In this example, we call a 2-layer recurrent SNN, 64 neurons per hidden layer, trainable tau, fast-sigmoid and max-over-time loss function. \
# A summary of the layer connectivity and parameter size is printed. \
# For more options and details, see the [second example](02_models_and_parameters.ipynb)

# %%
snn = RSNN_2l(dataset, num_hidden=64, thresh=0.3, tau_m='adp', win=time_window, surr='fs', loss_fn ='mot', batch_size=256, device=device)
snn.to(device)
# Out:
# RSNN_2l(
#   (criterion): CrossEntropyLoss()
#   (fc_ih): Linear(in_features=700, out_features=64, bias=False)
#   (fc_h1h1): Linear(in_features=64, out_features=64, bias=False)
#   (fc_h1h2): Linear(in_features=64, out_features=64, bias=False)
#   (fc_h2h2): Linear(in_features=64, out_features=64, bias=False)
#   (fc_ho): Linear(in_features=64, out_features=20, bias=False)
# )

# %% [markdown]
# ### Training

# %% [markdown]
# Arguments for training:
# - **snn**: the snn object to be trained.
# - **data**: the dataloader tuple (train_loader, test_loader) used to train 'snn'.
# - **learning_rate**: learning rate.
# - **num_epochs**: number of epochs.
# - **spkreg**: Spiking activity regularizer, added to the loss as avg_spikes_hidden_layer x spkreg. Default = 0.0
# - **l1_reg**: L1 regularizer (still in development) Default = 0.0
# - **dropout**: Random dropout ratio for the input spikes. Ranging form 0.0 to 1.0. Default = 0.0
# - **lr_scale**: Scaling of the learning rate of the tau_m and the tau_adp. Default = (2.0, 5.0)
# - **ckpt_dir**: Creates a folder in PYTHON_DRIVE_PATH/checkpoints to store the saved models. Default = 'checkpoint'
# - **test_fn**: This is to control the testing behavior (see AddTask example below). Default = None -> test every 5 epochs
# - **scheduler**: Scheduler for the learning rate: Default =(1, 0.98) -> multiply learning_rate by 0.98 every 1 epoch
#
# Prints total synaptic parameters and total mult-adds. \
# Also the training loss per epoch and time elapsed.

# %%
ckpt_dir = 'examples' # donde se guardará
train(snn, data, learning_rate=1e-3, num_epochs=10, ckpt_dir=ckpt_dir)
# Out:
# RSNN_2l(
#   (criterion): CrossEntropyLoss()
#   (fc_ih): Linear(in_features=700, out_features=64, bias=False)
#   (fc_h1h1): Linear(in_features=64, out_features=64, bias=False)
#   (fc_h1h2): Linear(in_features=64, out_features=64, bias=False)
#   (fc_h2h2): Linear(in_features=64, out_features=64, bias=False)
#   (fc_ho): Linear(in_features=64, out_features=20, bias=False)
# )
# Total params: 58368
# Total mult-adds (M): 2.9184
# training shd50_RSNN_2l_64.t7 for 10 epochs...
# Epoch [1/10]
# Step [10/31], Loss: 30.61188
# Step [20/31], Loss: 29.40914
# Step [30/31], Loss: 27.88741
# Time elasped: 52.7952036857605
# Epoch [2/10]
# Step [10/31], Loss: 25.93411
# Step [20/31], Loss: 23.96718
# Step [30/31], Loss: 22.57701
# Time elasped: 7.00411581993103
# Epoch [3/10]
# Step [10/31], Loss: 21.23886
# Step [20/31], Loss: 20.48669
# Step [30/31], Loss: 19.20707
# Time elasped: 5.514800310134888
# Epoch [4/10]
# Step [10/31], Loss: 17.54392
# Step [20/31], Loss: 16.24745
# Step [30/31], Loss: 15.16832
# Time elasped: 5.700109958648682
# Epoch [5/10]
# Step [10/31], Loss: 14.14838
# Step [20/31], Loss: 13.05664
# Step [30/31], Loss: 12.08887
# Time elasped: 6.10178279876709
# Test Loss: 1.5104753630501884
# Avg spk_count per neuron for all 50 timesteps 12.12082290649414
# Test Accuracy of the model on the test samples: 57.568
# Epoch [6/10]
# Step [10/31], Loss: 11.79412
# Step [20/31], Loss: 10.84596
# Step [30/31], Loss: 10.58545
# Time elasped: 6.400513648986816
# Epoch [7/10]
# Step [10/31], Loss: 9.94946
# Step [20/31], Loss: 9.70869
# Step [30/31], Loss: 9.31118
# Time elasped: 6.490355491638184
# Epoch [8/10]
# Step [10/31], Loss: 8.16279
# Step [20/31], Loss: 8.66629
# Step [30/31], Loss: 8.39813
# Time elasped: 6.528417587280273
# Epoch [9/10]
# Step [10/31], Loss: 7.39359
# Step [20/31], Loss: 7.04275
# Step [30/31], Loss: 6.89828
# Time elasped: 6.547283172607422
# Epoch [10/10]
# Step [10/31], Loss: 6.56671
# Step [20/31], Loss: 7.16501
# Step [30/31], Loss: 6.96786
# Time elasped: 6.481112957000732
# Test Loss: 1.3352840117045812
# Avg spk_count per neuron for all 50 timesteps 13.315876007080078
# Test Accuracy of the model on the test samples: 63.428

# %% [markdown]
# ### Loading models

# %% [markdown]
# If all went correctly in the previous steps, there should be a file 'shd50_RSNN_2l_64.t7' in *PYTHON_DRIVE_PATH/checkpoints/examples* \
# You can load any model for future use by providing its model name, location, batch size and device (gpu or cpu).

# %%
modelname = 'shd50_RSNN_2l_64.t7'
loaded_snn = ModelLoader(modelname, ckpt_dir, batch_size, device)
# Out:
# instance of <class 'dsnn.rsnn.RSNN_2l'> loaded sucessfully

# %%
loaded_snn.test(data[0])
# Out:
# Test Loss: 1.3417894840240479
# Avg spk_count per neuron for all 50 timesteps 13.314739227294922
# Test Accuracy of the model on the test samples: 63.623

# %% [markdown]
# ### Custom dataloader: Adding Task

# %% [markdown]
# Here is an example of training with a 'non-tonic' dataloader. \
# the test_fn function is used for customizing the behavior in testing. In this case, we tell the training function to test every 5 epochs and display a custom 'correct' measure.

# %%
from dsnn.rsnn_delays import RSNN_d_d
from dsnn.custom_dataloader import AddTaskDatasetLoader
from torch.utils.data import DataLoader

batch_size = 128 # 128: anil kag
time_window =50
d_train = AddTaskDatasetLoader(time_window, batch_size, randomness=True)
d_test = AddTaskDatasetLoader(time_window, batch_size, randomness=True) # 2560 from schmiduber paper
train_loader = DataLoader(d_train, batch_size=batch_size, num_workers=0)
test_loader = DataLoader(d_test, batch_size=batch_size, num_workers=0)

data = train_loader, test_loader # the dataloader tuple

def test_fn(snn, ckpt_dir, test_loader, max_acc, epoch):
    if (epoch + 1) % 5 == 0:
        for images, labels in test_loader:
            pred, ref = snn.propagate(images.to(device), labels.to(device))          
        correct = torch.sum(abs(pred-ref) < 0.04)
        print(f'Test set accuracy: {100*correct.item()/len(images)}% ')
        print('--------------------------')
    return max_acc

# %%
surr='fs'
n_h = 128
name= f'add2_{time_window}_rnn_{n_h}_{surr}'
ckpt_dir = 'some-tests-add'

hidden = (n_h, 1, 'r')
snn = RSNN_d_d('custom_2_1_{}'.format(batch_size), hidden=hidden, delay =(1,1), thresh=0.3,reset_to_zero = False,  tau_m='adp', win=time_window, surr=surr,  loss_fn ='prediction', batch_size=batch_size, device=device)
snn.debug=True
snn.to(device)

train(snn, data, 1e-3, 500, ckpt_dir=ckpt_dir, l1_reg=0.0, test_fn=test_fn, scheduler=False)
snn.save_model(name, ckpt_dir)
# Out:
# delays: [0]
# RSNN_d_d(
#   (criterion): MSELoss()
#   (f0_i): Linear(in_features=2, out_features=128, bias=False)
#   (r1_r1): Linear(in_features=128, out_features=128, bias=False)
#   (r1_o): Linear(in_features=128, out_features=1, bias=False)
# )
# Total params: 16768
# Total mult-adds (M): 0.8384
# training custom_2_1_12850_RSNN_d_d_1_l128_1d1.t7 for 500 epochs...
# Epoch [1/500]
# Step [1/1], Loss: 0.85173
# Time elasped: 0.14700007438659668
# Epoch [2/500]
# Step [1/1], Loss: 0.46957
# Time elasped: 0.1432359218597412
# Epoch [3/500]
# Step [1/1], Loss: 0.25574
# Time elasped: 0.14203596115112305
# Epoch [4/500]
# Step [1/1], Loss: 0.19644
# Time elasped: 0.14397001266479492
# Epoch [5/500]
# Step [1/1], Loss: 0.20863
# Time elasped: 0.1441822052001953
# Test set accuracy: 3.125%
# --------------------------
# Epoch [6/500]
# Step [1/1], Loss: 0.28645
# Time elasped: 0.1490001678466797
# Epoch [7/500]
# Step [1/1], Loss: 0.29216
# Time elasped: 0.14700007438659668
# Epoch [8/500]
# Step [1/1], Loss: 0.27546
# Time elasped: 0.14202356338500977
# Epoch [9/500]
# Step [1/1], Loss: 0.22854
# Time elasped: 0.14701080322265625
# Epoch [10/500]
# Step [1/1], Loss: 0.20585
# Time elasped: 0.14899897575378418
# Test set accuracy: 10.15625%
# --------------------------
# Epoch [11/500]
# Step [1/1], Loss: 0.16732
# Time elasped: 0.14260125160217285
# Epoch [12/500]
# Step [1/1], Loss: 0.14339
# Time elasped: 0.14397072792053223
# Epoch [13/500]
# Step [1/1], Loss: 0.15644
# Time elasped: 0.13899993896484375
# Epoch [14/500]
# Step [1/1], Loss: 0.17997
# Time elasped: 0.14400196075439453
# Epoch [15/500]
# Step [1/1], Loss: 0.18494
# Time elasped: 0.14527559280395508
# Test set accuracy: 7.03125%
# --------------------------
# Epoch [16/500]
# Step [1/1], Loss: 0.20297
# Time elasped: 0.14899969100952148
# Epoch [17/500]
# Step [1/1], Loss: 0.23883
# Time elasped: 0.14599990844726562
# Epoch [18/500]
# Step [1/1], Loss: 0.17691
# Time elasped: 0.14300012588500977
# Epoch [19/500]
# Step [1/1], Loss: 0.20780
# Time elasped: 0.14400029182434082
# Epoch [20/500]
# Step [1/1], Loss: 0.18851
# Time elasped: 0.14400005340576172
# Test set accuracy: 5.46875%
# --------------------------
# Epoch [21/500]
# Step [1/1], Loss: 0.20211
# Time elasped: 0.14400005340576172
# Epoch [22/500]
# Step [1/1], Loss: 0.15527
# Time elasped: 0.1470015048980713
# Epoch [23/500]
# Step [1/1], Loss: 0.16506
# Time elasped: 0.1525266170501709
# Epoch [24/500]
# Step [1/1], Loss: 0.14464
# Time elasped: 0.14700031280517578
# Epoch [25/500]
# Step [1/1], Loss: 0.16325
# Time elasped: 0.14299988746643066
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [26/500]
# Step [1/1], Loss: 0.19176
# Time elasped: 0.14500117301940918
# Epoch [27/500]
# Step [1/1], Loss: 0.16145
# Time elasped: 0.1419987678527832
# Epoch [28/500]
# Step [1/1], Loss: 0.18429
# Time elasped: 0.1400010585784912
# Epoch [29/500]
# Step [1/1], Loss: 0.17889
# Time elasped: 0.1440284252166748
# Epoch [30/500]
# Step [1/1], Loss: 0.18556
# Time elasped: 0.1425800323486328
# Test set accuracy: 6.25%
# --------------------------
# Epoch [31/500]
# Step [1/1], Loss: 0.16413
# Time elasped: 0.14200043678283691
# Epoch [32/500]
# Step [1/1], Loss: 0.20134
# Time elasped: 0.1439988613128662
# Epoch [33/500]
# Step [1/1], Loss: 0.22453
# Time elasped: 0.14300084114074707
# Epoch [34/500]
# Step [1/1], Loss: 0.16652
# Time elasped: 0.14431023597717285
# Epoch [35/500]
# Step [1/1], Loss: 0.18379
# Time elasped: 0.14100050926208496
# Test set accuracy: 10.15625%
# --------------------------
# Epoch [36/500]
# Step [1/1], Loss: 0.14871
# Time elasped: 0.14500164985656738
# Epoch [37/500]
# Step [1/1], Loss: 0.14393
# Time elasped: 0.1440281867980957
# Epoch [38/500]
# Step [1/1], Loss: 0.19580
# Time elasped: 0.14300060272216797
# Epoch [39/500]
# Step [1/1], Loss: 0.20369
# Time elasped: 0.14700531959533691
# Epoch [40/500]
# Step [1/1], Loss: 0.17914
# Time elasped: 0.14296531677246094
# Test set accuracy: 6.25%
# --------------------------
# Epoch [41/500]
# Step [1/1], Loss: 0.14271
# Time elasped: 0.14302921295166016
# Epoch [42/500]
# Step [1/1], Loss: 0.15821
# Time elasped: 0.14100050926208496
# Epoch [43/500]
# Step [1/1], Loss: 0.15987
# Time elasped: 0.14500021934509277
# Epoch [44/500]
# Step [1/1], Loss: 0.18538
# Time elasped: 0.14403676986694336
# Epoch [45/500]
# Step [1/1], Loss: 0.19157
# Time elasped: 0.14196300506591797
# Test set accuracy: 10.15625%
# --------------------------
# Epoch [46/500]
# Step [1/1], Loss: 0.20383
# Time elasped: 0.14299893379211426
# Epoch [47/500]
# Step [1/1], Loss: 0.15518
# Time elasped: 0.14400076866149902
# Epoch [48/500]
# Step [1/1], Loss: 0.15387
# Time elasped: 0.14353489875793457
# Epoch [49/500]
# Step [1/1], Loss: 0.19809
# Time elasped: 0.14100003242492676
# Epoch [50/500]
# Step [1/1], Loss: 0.19746
# Time elasped: 0.14699959754943848
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [51/500]
# Step [1/1], Loss: 0.15332
# Time elasped: 0.14200115203857422
# Epoch [52/500]
# Step [1/1], Loss: 0.15851
# Time elasped: 0.14418554306030273
# Epoch [53/500]
# Step [1/1], Loss: 0.16134
# Time elasped: 0.13996529579162598
# Epoch [54/500]
# Step [1/1], Loss: 0.19024
# Time elasped: 0.1420001983642578
# Epoch [55/500]
# Step [1/1], Loss: 0.13674
# Time elasped: 0.14600062370300293
# Test set accuracy: 8.59375%
# --------------------------
# Epoch [56/500]
# Step [1/1], Loss: 0.14575
# Time elasped: 0.14100027084350586
# Epoch [57/500]
# Step [1/1], Loss: 0.16668
# Time elasped: 0.14099979400634766
# Epoch [58/500]
# Step [1/1], Loss: 0.16745
# Time elasped: 0.15000033378601074
# Epoch [59/500]
# Step [1/1], Loss: 0.16399
# Time elasped: 0.14400005340576172
# Epoch [60/500]
# Step [1/1], Loss: 0.21720
# Time elasped: 0.1529998779296875
# Test set accuracy: 6.25%
# --------------------------
# Epoch [61/500]
# Step [1/1], Loss: 0.16056
# Time elasped: 0.1426997184753418
# Epoch [62/500]
# Step [1/1], Loss: 0.18615
# Time elasped: 0.16002893447875977
# Epoch [63/500]
# Step [1/1], Loss: 0.18053
# Time elasped: 0.14197111129760742
# Epoch [64/500]
# Step [1/1], Loss: 0.17326
# Time elasped: 0.14600014686584473
# Epoch [65/500]
# Step [1/1], Loss: 0.15304
# Time elasped: 0.14299964904785156
# Test set accuracy: 6.25%
# --------------------------
# Epoch [66/500]
# Step [1/1], Loss: 0.16269
# Time elasped: 0.14100122451782227
# Epoch [67/500]
# Step [1/1], Loss: 0.15450
# Time elasped: 0.14456820487976074
# Epoch [68/500]
# Step [1/1], Loss: 0.19109
# Time elasped: 0.14297032356262207
# Epoch [69/500]
# Step [1/1], Loss: 0.18081
# Time elasped: 0.14500665664672852
# Epoch [70/500]
# Step [1/1], Loss: 0.16232
# Time elasped: 0.14299368858337402
# Test set accuracy: 6.25%
# --------------------------
# Epoch [71/500]
# Step [1/1], Loss: 0.18233
# Time elasped: 0.14424538612365723
# Epoch [72/500]
# Step [1/1], Loss: 0.17254
# Time elasped: 0.14600086212158203
# Epoch [73/500]
# Step [1/1], Loss: 0.16833
# Time elasped: 0.1439990997314453
# Epoch [74/500]
# Step [1/1], Loss: 0.19023
# Time elasped: 0.14500069618225098
# Epoch [75/500]
# Step [1/1], Loss: 0.18374
# Time elasped: 0.14303135871887207
# Test set accuracy: 5.46875%
# --------------------------
# Epoch [76/500]
# Step [1/1], Loss: 0.15960
# Time elasped: 0.14102888107299805
# Epoch [77/500]
# Step [1/1], Loss: 0.15922
# Time elasped: 0.1469712257385254
# Epoch [78/500]
# Step [1/1], Loss: 0.21505
# Time elasped: 0.14299964904785156
# Epoch [79/500]
# Step [1/1], Loss: 0.19441
# Time elasped: 0.14403462409973145
# Epoch [80/500]
# Step [1/1], Loss: 0.15564
# Time elasped: 0.1439521312713623
# Test set accuracy: 9.375%
# --------------------------
# Epoch [81/500]
# Step [1/1], Loss: 0.17005
# Time elasped: 0.14400005340576172
# Epoch [82/500]
# Step [1/1], Loss: 0.16505
# Time elasped: 0.143998384475708
# Epoch [83/500]
# Step [1/1], Loss: 0.15209
# Time elasped: 0.14200091361999512
# Epoch [84/500]
# Step [1/1], Loss: 0.18156
# Time elasped: 0.14300084114074707
# Epoch [85/500]
# Step [1/1], Loss: 0.15837
# Time elasped: 0.14299964904785156
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [86/500]
# Step [1/1], Loss: 0.15846
# Time elasped: 0.14300012588500977
# Epoch [87/500]
# Step [1/1], Loss: 0.15950
# Time elasped: 0.141998291015625
# Epoch [88/500]
# Step [1/1], Loss: 0.18347
# Time elasped: 0.14400124549865723
# Epoch [89/500]
# Step [1/1], Loss: 0.20791
# Time elasped: 0.14100003242492676
# Epoch [90/500]
# Step [1/1], Loss: 0.19169
# Time elasped: 0.14662694931030273
# Test set accuracy: 6.25%
# --------------------------
# Epoch [91/500]
# Step [1/1], Loss: 0.17893
# Time elasped: 0.14300274848937988
# Epoch [92/500]
# Step [1/1], Loss: 0.19581
# Time elasped: 0.1439979076385498
# Epoch [93/500]
# Step [1/1], Loss: 0.17061
# Time elasped: 0.14300012588500977
# Epoch [94/500]
# Step [1/1], Loss: 0.18277
# Time elasped: 0.14400029182434082
# Epoch [95/500]
# Step [1/1], Loss: 0.15508
# Time elasped: 0.1419994831085205
# Test set accuracy: 11.71875%
# --------------------------
# Epoch [96/500]
# Step [1/1], Loss: 0.16566
# Time elasped: 0.14800000190734863
# Epoch [97/500]
# Step [1/1], Loss: 0.17952
# Time elasped: 0.14500021934509277
# Epoch [98/500]
# Step [1/1], Loss: 0.18375
# Time elasped: 0.14098882675170898
# Epoch [99/500]
# Step [1/1], Loss: 0.17155
# Time elasped: 0.1439971923828125
# Epoch [100/500]
# Step [1/1], Loss: 0.17003
# Time elasped: 0.14397048950195312
# Test set accuracy: 4.6875%
# --------------------------
# Epoch [101/500]
# Step [1/1], Loss: 0.16941
# Time elasped: 0.14699959754943848
# Epoch [102/500]
# Step [1/1], Loss: 0.16180
# Time elasped: 0.14400005340576172
# Epoch [103/500]
# Step [1/1], Loss: 0.17591
# Time elasped: 0.14399957656860352
# Epoch [104/500]
# Step [1/1], Loss: 0.17077
# Time elasped: 0.14556646347045898
# Epoch [105/500]
# Step [1/1], Loss: 0.18791
# Time elasped: 0.14303207397460938
# Test set accuracy: 8.59375%
# --------------------------
# Epoch [106/500]
# Step [1/1], Loss: 0.19726
# Time elasped: 0.1509993076324463
# Epoch [107/500]
# Step [1/1], Loss: 0.15519
# Time elasped: 0.14599943161010742
# Epoch [108/500]
# Step [1/1], Loss: 0.16041
# Time elasped: 0.14313435554504395
# Epoch [109/500]
# Step [1/1], Loss: 0.17503
# Time elasped: 0.14499974250793457
# Epoch [110/500]
# Step [1/1], Loss: 0.13410
# Time elasped: 0.14200115203857422
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [111/500]
# Step [1/1], Loss: 0.17202
# Time elasped: 0.1400003433227539
# Epoch [112/500]
# Step [1/1], Loss: 0.16161
# Time elasped: 0.14099788665771484
# Epoch [113/500]
# Step [1/1], Loss: 0.16201
# Time elasped: 0.13903021812438965
# Epoch [114/500]
# Step [1/1], Loss: 0.18240
# Time elasped: 0.14500021934509277
# Epoch [115/500]
# Step [1/1], Loss: 0.15348
# Time elasped: 0.14397048950195312
# Test set accuracy: 9.375%
# --------------------------
# Epoch [116/500]
# Step [1/1], Loss: 0.16085
# Time elasped: 0.14500021934509277
# Epoch [117/500]
# Step [1/1], Loss: 0.19574
# Time elasped: 0.14532923698425293
# Epoch [118/500]
# Step [1/1], Loss: 0.17691
# Time elasped: 0.14757299423217773
# Epoch [119/500]
# Step [1/1], Loss: 0.17226
# Time elasped: 0.14853906631469727
# Epoch [120/500]
# Step [1/1], Loss: 0.16202
# Time elasped: 0.1469707489013672
# Test set accuracy: 11.71875%
# --------------------------
# Epoch [121/500]
# Step [1/1], Loss: 0.17829
# Time elasped: 0.14800047874450684
# Epoch [122/500]
# Step [1/1], Loss: 0.17898
# Time elasped: 0.14399957656860352
# Epoch [123/500]
# Step [1/1], Loss: 0.14292
# Time elasped: 0.14300179481506348
# Epoch [124/500]
# Step [1/1], Loss: 0.14536
# Time elasped: 0.1439981460571289
# Epoch [125/500]
# Step [1/1], Loss: 0.18509
# Time elasped: 0.14300251007080078
# Test set accuracy: 6.25%
# --------------------------
# Epoch [126/500]
# Step [1/1], Loss: 0.17166
# Time elasped: 0.14899873733520508
# Epoch [127/500]
# Step [1/1], Loss: 0.17960
# Time elasped: 0.14324522018432617
# Epoch [128/500]
# Step [1/1], Loss: 0.18209
# Time elasped: 0.14400076866149902
# Epoch [129/500]
# Step [1/1], Loss: 0.18063
# Time elasped: 0.14500021934509277
# Epoch [130/500]
# Step [1/1], Loss: 0.17862
# Time elasped: 0.1460413932800293
# Test set accuracy: 10.15625%
# --------------------------
# Epoch [131/500]
# Step [1/1], Loss: 0.17007
# Time elasped: 0.1509695053100586
# Epoch [132/500]
# Step [1/1], Loss: 0.19501
# Time elasped: 0.15400099754333496
# Epoch [133/500]
# Step [1/1], Loss: 0.14750
# Time elasped: 0.14603209495544434
# Epoch [134/500]
# Step [1/1], Loss: 0.16824
# Time elasped: 0.14696955680847168
# Epoch [135/500]
# Step [1/1], Loss: 0.19597
# Time elasped: 0.14732074737548828
# Test set accuracy: 4.6875%
# --------------------------
# Epoch [136/500]
# Step [1/1], Loss: 0.17665
# Time elasped: 0.14700078964233398
# Epoch [137/500]
# Step [1/1], Loss: 0.13449
# Time elasped: 0.14599967002868652
# Epoch [138/500]
# Step [1/1], Loss: 0.15068
# Time elasped: 0.14400053024291992
# Epoch [139/500]
# Step [1/1], Loss: 0.17328
# Time elasped: 0.14400029182434082
# Epoch [140/500]
# Step [1/1], Loss: 0.15419
# Time elasped: 0.14502835273742676
# Test set accuracy: 3.125%
# --------------------------
# Epoch [141/500]
# Step [1/1], Loss: 0.16609
# Time elasped: 0.14357423782348633
# Epoch [142/500]
# Step [1/1], Loss: 0.15661
# Time elasped: 0.14399957656860352
# Epoch [143/500]
# Step [1/1], Loss: 0.18384
# Time elasped: 0.14499998092651367
# Epoch [144/500]
# Step [1/1], Loss: 0.15696
# Time elasped: 0.14101839065551758
# Epoch [145/500]
# Step [1/1], Loss: 0.14537
# Time elasped: 0.14374876022338867
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [146/500]
# Step [1/1], Loss: 0.16804
# Time elasped: 0.14300036430358887
# Epoch [147/500]
# Step [1/1], Loss: 0.15702
# Time elasped: 0.1530017852783203
# Epoch [148/500]
# Step [1/1], Loss: 0.15864
# Time elasped: 0.14499807357788086
# Epoch [149/500]
# Step [1/1], Loss: 0.15779
# Time elasped: 0.14602947235107422
# Epoch [150/500]
# Step [1/1], Loss: 0.14918
# Time elasped: 0.14597010612487793
# Test set accuracy: 3.90625%
# --------------------------
# Epoch [151/500]
# Step [1/1], Loss: 0.14384
# Time elasped: 0.14800000190734863
# Epoch [152/500]
# Step [1/1], Loss: 0.15456
# Time elasped: 0.14499998092651367
# Epoch [153/500]
# Step [1/1], Loss: 0.16243
# Time elasped: 0.14299988746643066
# Epoch [154/500]
# Step [1/1], Loss: 0.17744
# Time elasped: 0.14184021949768066
# Epoch [155/500]
# Step [1/1], Loss: 0.16765
# Time elasped: 0.14299798011779785
# Test set accuracy: 10.15625%
# --------------------------
# Epoch [156/500]
# Step [1/1], Loss: 0.17997
# Time elasped: 0.1470015048980713
# Epoch [157/500]
# Step [1/1], Loss: 0.14928
# Time elasped: 0.14499998092651367
# Epoch [158/500]
# Step [1/1], Loss: 0.20712
# Time elasped: 0.14599943161010742
# Epoch [159/500]
# Step [1/1], Loss: 0.15878
# Time elasped: 0.14402246475219727
# Epoch [160/500]
# Step [1/1], Loss: 0.20940
# Time elasped: 0.14357233047485352
# Test set accuracy: 4.6875%
# --------------------------
# Epoch [161/500]
# Step [1/1], Loss: 0.18288
# Time elasped: 0.1419999599456787
# Epoch [162/500]
# Step [1/1], Loss: 0.17098
# Time elasped: 0.14499998092651367
# Epoch [163/500]
# Step [1/1], Loss: 0.17304
# Time elasped: 0.1490006446838379
# Epoch [164/500]
# Step [1/1], Loss: 0.19346
# Time elasped: 0.1462869644165039
# Epoch [165/500]
# Step [1/1], Loss: 0.14386
# Time elasped: 0.13902950286865234
# Test set accuracy: 8.59375%
# --------------------------
# Epoch [166/500]
# Step [1/1], Loss: 0.18370
# Time elasped: 0.1440286636352539
# Epoch [167/500]
# Step [1/1], Loss: 0.17593
# Time elasped: 0.14497089385986328
# Epoch [168/500]
# Step [1/1], Loss: 0.19876
# Time elasped: 0.15400314331054688
# Epoch [169/500]
# Step [1/1], Loss: 0.15042
# Time elasped: 0.14600038528442383
# Epoch [170/500]
# Step [1/1], Loss: 0.15816
# Time elasped: 0.14399981498718262
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [171/500]
# Step [1/1], Loss: 0.22153
# Time elasped: 0.14200186729431152
# Epoch [172/500]
# Step [1/1], Loss: 0.16079
# Time elasped: 0.15205001831054688
# Epoch [173/500]
# Step [1/1], Loss: 0.17584
# Time elasped: 0.14599990844726562
# Epoch [174/500]
# Step [1/1], Loss: 0.12262
# Time elasped: 0.14602899551391602
# Epoch [175/500]
# Step [1/1], Loss: 0.17246
# Time elasped: 0.14497113227844238
# Test set accuracy: 8.59375%
# --------------------------
# Epoch [176/500]
# Step [1/1], Loss: 0.17469
# Time elasped: 0.14100170135498047
# Epoch [177/500]
# Step [1/1], Loss: 0.17097
# Time elasped: 0.1440281867980957
# Epoch [178/500]
# Step [1/1], Loss: 0.15832
# Time elasped: 0.1435401439666748
# Epoch [179/500]
# Step [1/1], Loss: 0.15736
# Time elasped: 0.1419994831085205
# Epoch [180/500]
# Step [1/1], Loss: 0.16253
# Time elasped: 0.1510322093963623
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [181/500]
# Step [1/1], Loss: 0.18856
# Time elasped: 0.14500069618225098
# Epoch [182/500]
# Step [1/1], Loss: 0.16570
# Time elasped: 0.1454465389251709
# Epoch [183/500]
# Step [1/1], Loss: 0.15519
# Time elasped: 0.1460285186767578
# Epoch [184/500]
# Step [1/1], Loss: 0.16747
# Time elasped: 0.1509714126586914
# Epoch [185/500]
# Step [1/1], Loss: 0.16360
# Time elasped: 0.14399957656860352
# Test set accuracy: 7.03125%
# --------------------------
# Epoch [186/500]
# Step [1/1], Loss: 0.17150
# Time elasped: 0.1400001049041748
# Epoch [187/500]
# Step [1/1], Loss: 0.13042
# Time elasped: 0.14403057098388672
# Epoch [188/500]
# Step [1/1], Loss: 0.16563
# Time elasped: 0.14299917221069336
# Epoch [189/500]
# Step [1/1], Loss: 0.20934
# Time elasped: 0.14296913146972656
# Epoch [190/500]
# Step [1/1], Loss: 0.16690
# Time elasped: 0.14400053024291992
# Test set accuracy: 7.03125%
# --------------------------
# Epoch [191/500]
# Step [1/1], Loss: 0.17119
# Time elasped: 0.14599895477294922
# Epoch [192/500]
# Step [1/1], Loss: 0.16977
# Time elasped: 0.1530001163482666
# Epoch [193/500]
# Step [1/1], Loss: 0.18585
# Time elasped: 0.14499974250793457
# Epoch [194/500]
# Step [1/1], Loss: 0.18285
# Time elasped: 0.14502954483032227
# Epoch [195/500]
# Step [1/1], Loss: 0.15429
# Time elasped: 0.14397072792053223
# Test set accuracy: 8.59375%
# --------------------------
# Epoch [196/500]
# Step [1/1], Loss: 0.17621
# Time elasped: 0.1445772647857666
# Epoch [197/500]
# Step [1/1], Loss: 0.15862
# Time elasped: 0.14797043800354004
# Epoch [198/500]
# Step [1/1], Loss: 0.16486
# Time elasped: 0.14400029182434082
# Epoch [199/500]
# Step [1/1], Loss: 0.14430
# Time elasped: 0.14400386810302734
# Epoch [200/500]
# Step [1/1], Loss: 0.14824
# Time elasped: 0.14699578285217285
# Test set accuracy: 5.46875%
# --------------------------
# Epoch [201/500]
# Step [1/1], Loss: 0.16261
# Time elasped: 0.14429068565368652
# Epoch [202/500]
# Step [1/1], Loss: 0.17344
# Time elasped: 0.14099979400634766
# Epoch [203/500]
# Step [1/1], Loss: 0.20216
# Time elasped: 0.14300012588500977
# Epoch [204/500]
# Step [1/1], Loss: 0.18717
# Time elasped: 0.14800095558166504
# Epoch [205/500]
# Step [1/1], Loss: 0.18602
# Time elasped: 0.1419987678527832
# Test set accuracy: 6.25%
# --------------------------
# Epoch [206/500]
# Step [1/1], Loss: 0.16203
# Time elasped: 0.14502954483032227
# Epoch [207/500]
# Step [1/1], Loss: 0.14706
# Time elasped: 0.14596986770629883
# Epoch [208/500]
# Step [1/1], Loss: 0.15307
# Time elasped: 0.14303302764892578
# Epoch [209/500]
# Step [1/1], Loss: 0.15698
# Time elasped: 0.14647197723388672
# Epoch [210/500]
# Step [1/1], Loss: 0.18576
# Time elasped: 0.14403128623962402
# Test set accuracy: 9.375%
# --------------------------
# Epoch [211/500]
# Step [1/1], Loss: 0.15305
# Time elasped: 0.1420001983642578
# Epoch [212/500]
# Step [1/1], Loss: 0.15943
# Time elasped: 0.14700031280517578
# Epoch [213/500]
# Step [1/1], Loss: 0.17783
# Time elasped: 0.14699983596801758
# Epoch [214/500]
# Step [1/1], Loss: 0.18933
# Time elasped: 0.14902901649475098
# Epoch [215/500]
# Step [1/1], Loss: 0.18954
# Time elasped: 0.14358806610107422
# Test set accuracy: 7.03125%
# --------------------------
# Epoch [216/500]
# Step [1/1], Loss: 0.17828
# Time elasped: 0.14500045776367188
# Epoch [217/500]
# Step [1/1], Loss: 0.17507
# Time elasped: 0.14799976348876953
# Epoch [218/500]
# Step [1/1], Loss: 0.15517
# Time elasped: 0.14600014686584473
# Epoch [219/500]
# Step [1/1], Loss: 0.17049
# Time elasped: 0.14499998092651367
# Epoch [220/500]
# Step [1/1], Loss: 0.18856
# Time elasped: 0.14529991149902344
# Test set accuracy: 8.59375%
# --------------------------
# Epoch [221/500]
# Step [1/1], Loss: 0.13285
# Time elasped: 0.1439990997314453
# Epoch [222/500]
# Step [1/1], Loss: 0.13101
# Time elasped: 0.15002870559692383
# Epoch [223/500]
# Step [1/1], Loss: 0.16593
# Time elasped: 0.14497137069702148
# Epoch [224/500]
# Step [1/1], Loss: 0.19371
# Time elasped: 0.14899992942810059
# Epoch [225/500]
# Step [1/1], Loss: 0.19327
# Time elasped: 0.1399996280670166
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [226/500]
# Step [1/1], Loss: 0.13409
# Time elasped: 0.14500093460083008
# Epoch [227/500]
# Step [1/1], Loss: 0.18719
# Time elasped: 0.14909887313842773
# Epoch [228/500]
# Step [1/1], Loss: 0.18962
# Time elasped: 0.14399981498718262
# Epoch [229/500]
# Step [1/1], Loss: 0.16848
# Time elasped: 0.14800000190734863
# Epoch [230/500]
# Step [1/1], Loss: 0.13881
# Time elasped: 0.14200234413146973
# Test set accuracy: 10.15625%
# --------------------------
# Epoch [231/500]
# Step [1/1], Loss: 0.13991
# Time elasped: 0.1440286636352539
# Epoch [232/500]
# Step [1/1], Loss: 0.17466
# Time elasped: 0.15697121620178223
# Epoch [233/500]
# Step [1/1], Loss: 0.18450
# Time elasped: 0.14099979400634766
# Epoch [234/500]
# Step [1/1], Loss: 0.15955
# Time elasped: 0.14359307289123535
# Epoch [235/500]
# Step [1/1], Loss: 0.16792
# Time elasped: 0.14799880981445312
# Test set accuracy: 6.25%
# --------------------------
# Epoch [236/500]
# Step [1/1], Loss: 0.15979
# Time elasped: 0.14500212669372559
# Epoch [237/500]
# Step [1/1], Loss: 0.16369
# Time elasped: 0.1419994831085205
# Epoch [238/500]
# Step [1/1], Loss: 0.16156
# Time elasped: 0.1403946876525879
# Epoch [239/500]
# Step [1/1], Loss: 0.17376
# Time elasped: 0.14097094535827637
# Epoch [240/500]
# Step [1/1], Loss: 0.14765
# Time elasped: 0.14602923393249512
# Test set accuracy: 4.6875%
# --------------------------
# Epoch [241/500]
# Step [1/1], Loss: 0.16639
# Time elasped: 0.1419990062713623
# Epoch [242/500]
# Step [1/1], Loss: 0.19336
# Time elasped: 0.14200067520141602
# Epoch [243/500]
# Step [1/1], Loss: 0.18748
# Time elasped: 0.15799999237060547
# Epoch [244/500]
# Step [1/1], Loss: 0.17577
# Time elasped: 0.14500093460083008
# Epoch [245/500]
# Step [1/1], Loss: 0.17837
# Time elasped: 0.14068317413330078
# Test set accuracy: 6.25%
# --------------------------
# Epoch [246/500]
# Step [1/1], Loss: 0.18965
# Time elasped: 0.14665770530700684
# Epoch [247/500]
# Step [1/1], Loss: 0.18277
# Time elasped: 0.143080472946167
# Epoch [248/500]
# Step [1/1], Loss: 0.19321
# Time elasped: 0.143035888671875
# Epoch [249/500]
# Step [1/1], Loss: 0.17608
# Time elasped: 0.1449718475341797
# Epoch [250/500]
# Step [1/1], Loss: 0.16496
# Time elasped: 0.143998384475708
# Test set accuracy: 6.25%
# --------------------------
# Epoch [251/500]
# Step [1/1], Loss: 0.16235
# Time elasped: 0.1399993896484375
# Epoch [252/500]
# Step [1/1], Loss: 0.15823
# Time elasped: 0.15355873107910156
# Epoch [253/500]
# Step [1/1], Loss: 0.16937
# Time elasped: 0.14399957656860352
# Epoch [254/500]
# Step [1/1], Loss: 0.15920
# Time elasped: 0.14403486251831055
# Epoch [255/500]
# Step [1/1], Loss: 0.16616
# Time elasped: 0.14496564865112305
# Test set accuracy: 10.9375%
# --------------------------
# Epoch [256/500]
# Step [1/1], Loss: 0.14551
# Time elasped: 0.1444103717803955
# Epoch [257/500]
# Step [1/1], Loss: 0.16015
# Time elasped: 0.14499974250793457
# Epoch [258/500]
# Step [1/1], Loss: 0.17402
# Time elasped: 0.1440291404724121
# Epoch [259/500]
# Step [1/1], Loss: 0.15034
# Time elasped: 0.14297103881835938
# Epoch [260/500]
# Step [1/1], Loss: 0.16602
# Time elasped: 0.14400005340576172
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [261/500]
# Step [1/1], Loss: 0.19588
# Time elasped: 0.14899587631225586
# Epoch [262/500]
# Step [1/1], Loss: 0.14978
# Time elasped: 0.14803147315979004
# Epoch [263/500]
# Step [1/1], Loss: 0.18285
# Time elasped: 0.1439683437347412
# Epoch [264/500]
# Step [1/1], Loss: 0.15934
# Time elasped: 0.14299869537353516
# Epoch [265/500]
# Step [1/1], Loss: 0.18593
# Time elasped: 0.1427161693572998
# Test set accuracy: 5.46875%
# --------------------------
# Epoch [266/500]
# Step [1/1], Loss: 0.18527
# Time elasped: 0.14500117301940918
# Epoch [267/500]
# Step [1/1], Loss: 0.17926
# Time elasped: 0.15503144264221191
# Epoch [268/500]
# Step [1/1], Loss: 0.16290
# Time elasped: 0.14350461959838867
# Epoch [269/500]
# Step [1/1], Loss: 0.16711
# Time elasped: 0.14102983474731445
# Epoch [270/500]
# Step [1/1], Loss: 0.18227
# Time elasped: 0.14300274848937988
# Test set accuracy: 5.46875%
# --------------------------
# Epoch [271/500]
# Step [1/1], Loss: 0.14880
# Time elasped: 0.14303135871887207
# Epoch [272/500]
# Step [1/1], Loss: 0.16462
# Time elasped: 0.14499759674072266
# Epoch [273/500]
# Step [1/1], Loss: 0.16740
# Time elasped: 0.14397287368774414
# Epoch [274/500]
# Step [1/1], Loss: 0.13736
# Time elasped: 0.14499807357788086
# Epoch [275/500]
# Step [1/1], Loss: 0.17074
# Time elasped: 0.1435854434967041
# Test set accuracy: 0.0%
# --------------------------
# Epoch [276/500]
# Step [1/1], Loss: 0.15314
# Time elasped: 0.14503145217895508
# Epoch [277/500]
# Step [1/1], Loss: 0.15769
# Time elasped: 0.14296913146972656
# Epoch [278/500]
# Step [1/1], Loss: 0.14315
# Time elasped: 0.14300203323364258
# Epoch [279/500]
# Step [1/1], Loss: 0.13849
# Time elasped: 0.14499759674072266
# Epoch [280/500]
# Step [1/1], Loss: 0.14566
# Time elasped: 0.14400029182434082
# Test set accuracy: 7.03125%
# --------------------------
# Epoch [281/500]
# Step [1/1], Loss: 0.16404
# Time elasped: 0.14499998092651367
# Epoch [282/500]
# Step [1/1], Loss: 0.18556
# Time elasped: 0.14503026008605957
# Epoch [283/500]
# Step [1/1], Loss: 0.16664
# Time elasped: 0.13909673690795898
# Epoch [284/500]
# Step [1/1], Loss: 0.17996
# Time elasped: 0.1430225372314453
# Epoch [285/500]
# Step [1/1], Loss: 0.16992
# Time elasped: 0.14397120475769043
# Test set accuracy: 3.125%
# --------------------------
# Epoch [286/500]
# Step [1/1], Loss: 0.16867
# Time elasped: 0.15999817848205566
# Epoch [287/500]
# Step [1/1], Loss: 0.16570
# Time elasped: 0.14399981498718262
# Epoch [288/500]
# Step [1/1], Loss: 0.14688
# Time elasped: 0.14300036430358887
# Epoch [289/500]
# Step [1/1], Loss: 0.16836
# Time elasped: 0.14161992073059082
# Epoch [290/500]
# Step [1/1], Loss: 0.16466
# Time elasped: 0.1429736614227295
# Test set accuracy: 8.59375%
# --------------------------
# Epoch [291/500]
# Step [1/1], Loss: 0.17182
# Time elasped: 0.14699792861938477
# Epoch [292/500]
# Step [1/1], Loss: 0.14089
# Time elasped: 0.14803171157836914
# Epoch [293/500]
# Step [1/1], Loss: 0.14257
# Time elasped: 0.14434552192687988
# Epoch [294/500]
# Step [1/1], Loss: 0.15437
# Time elasped: 0.14899992942810059
# Epoch [295/500]
# Step [1/1], Loss: 0.15444
# Time elasped: 0.14499950408935547
# Test set accuracy: 6.25%
# --------------------------
# Epoch [296/500]
# Step [1/1], Loss: 0.18546
# Time elasped: 0.14500069618225098
# Epoch [297/500]
# Step [1/1], Loss: 0.18252
# Time elasped: 0.1419999599456787
# Epoch [298/500]
# Step [1/1], Loss: 0.14139
# Time elasped: 0.14999818801879883
# Epoch [299/500]
# Step [1/1], Loss: 0.18674
# Time elasped: 0.14700055122375488
# Epoch [300/500]
# Step [1/1], Loss: 0.13523
# Time elasped: 0.15399980545043945
# Test set accuracy: 4.6875%
# --------------------------
# Epoch [301/500]
# Step [1/1], Loss: 0.15560
# Time elasped: 0.1437690258026123
# Epoch [302/500]
# Step [1/1], Loss: 0.17970
# Time elasped: 0.14386439323425293
# Epoch [303/500]
# Step [1/1], Loss: 0.15401
# Time elasped: 0.14596915245056152
# Epoch [304/500]
# Step [1/1], Loss: 0.17121
# Time elasped: 0.14500117301940918
# Epoch [305/500]
# Step [1/1], Loss: 0.16960
# Time elasped: 0.14999866485595703
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [306/500]
# Step [1/1], Loss: 0.17890
# Time elasped: 0.14303040504455566
# Epoch [307/500]
# Step [1/1], Loss: 0.17524
# Time elasped: 0.14151573181152344
# Epoch [308/500]
# Step [1/1], Loss: 0.19346
# Time elasped: 0.14200115203857422
# Epoch [309/500]
# Step [1/1], Loss: 0.16129
# Time elasped: 0.146240234375
# Epoch [310/500]
# Step [1/1], Loss: 0.15839
# Time elasped: 0.1440141201019287
# Test set accuracy: 4.6875%
# --------------------------
# Epoch [311/500]
# Step [1/1], Loss: 0.19852
# Time elasped: 0.1553792953491211
# Epoch [312/500]
# Step [1/1], Loss: 0.16782
# Time elasped: 0.1511240005493164
# Epoch [313/500]
# Step [1/1], Loss: 0.17354
# Time elasped: 0.14702963829040527
# Epoch [314/500]
# Step [1/1], Loss: 0.20849
# Time elasped: 0.15200066566467285
# Epoch [315/500]
# Step [1/1], Loss: 0.15583
# Time elasped: 0.14596867561340332
# Test set accuracy: 7.03125%
# --------------------------
# Epoch [316/500]
# Step [1/1], Loss: 0.14862
# Time elasped: 0.14603161811828613
# Epoch [317/500]
# Step [1/1], Loss: 0.19269
# Time elasped: 0.14596962928771973
# Epoch [318/500]
# Step [1/1], Loss: 0.13741
# Time elasped: 0.1419985294342041
# Epoch [319/500]
# Step [1/1], Loss: 0.16243
# Time elasped: 0.1400308609008789
# Epoch [320/500]
# Step [1/1], Loss: 0.17647
# Time elasped: 0.1440868377685547
# Test set accuracy: 7.03125%
# --------------------------
# Epoch [321/500]
# Step [1/1], Loss: 0.17422
# Time elasped: 0.1490004062652588
# Epoch [322/500]
# Step [1/1], Loss: 0.20527
# Time elasped: 0.14699959754943848
# Epoch [323/500]
# Step [1/1], Loss: 0.17894
# Time elasped: 0.14300012588500977
# Epoch [324/500]
# Step [1/1], Loss: 0.17600
# Time elasped: 0.14099979400634766
# Epoch [325/500]
# Step [1/1], Loss: 0.16211
# Time elasped: 0.14302921295166016
# Test set accuracy: 5.46875%
# --------------------------
# Epoch [326/500]
# Step [1/1], Loss: 0.18352
# Time elasped: 0.1435689926147461
# Epoch [327/500]
# Step [1/1], Loss: 0.15512
# Time elasped: 0.14599847793579102
# Epoch [328/500]
# Step [1/1], Loss: 0.14390
# Time elasped: 0.14800310134887695
# Epoch [329/500]
# Step [1/1], Loss: 0.14597
# Time elasped: 0.14799833297729492
# Epoch [330/500]
# Step [1/1], Loss: 0.16654
# Time elasped: 0.14724111557006836
# Test set accuracy: 6.25%
# --------------------------
# Epoch [331/500]
# Step [1/1], Loss: 0.17523
# Time elasped: 0.1490328311920166
# Epoch [332/500]
# Step [1/1], Loss: 0.15007
# Time elasped: 0.14400005340576172
# Epoch [333/500]
# Step [1/1], Loss: 0.18469
# Time elasped: 0.14400005340576172
# Epoch [334/500]
# Step [1/1], Loss: 0.18802
# Time elasped: 0.14503026008605957
# Epoch [335/500]
# Step [1/1], Loss: 0.12781
# Time elasped: 0.14499902725219727
# Test set accuracy: 7.03125%
# --------------------------
# Epoch [336/500]
# Step [1/1], Loss: 0.17525
# Time elasped: 0.14302849769592285
# Epoch [337/500]
# Step [1/1], Loss: 0.21136
# Time elasped: 0.14597082138061523
# Epoch [338/500]
# Step [1/1], Loss: 0.17128
# Time elasped: 0.14415717124938965
# Epoch [339/500]
# Step [1/1], Loss: 0.16806
# Time elasped: 0.14502906799316406
# Epoch [340/500]
# Step [1/1], Loss: 0.14604
# Time elasped: 0.1439971923828125
# Test set accuracy: 5.46875%
# --------------------------
# Epoch [341/500]
# Step [1/1], Loss: 0.16826
# Time elasped: 0.1410367488861084
# Epoch [342/500]
# Step [1/1], Loss: 0.13190
# Time elasped: 0.14551186561584473
# Epoch [343/500]
# Step [1/1], Loss: 0.12958
# Time elasped: 0.14302968978881836
# Epoch [344/500]
# Step [1/1], Loss: 0.15927
# Time elasped: 0.15254449844360352
# Epoch [345/500]
# Step [1/1], Loss: 0.21457
# Time elasped: 0.14499902725219727
# Test set accuracy: 4.6875%
# --------------------------
# Epoch [346/500]
# Step [1/1], Loss: 0.15583
# Time elasped: 0.14703750610351562
# Epoch [347/500]
# Step [1/1], Loss: 0.17189
# Time elasped: 0.14599895477294922
# Epoch [348/500]
# Step [1/1], Loss: 0.14786
# Time elasped: 0.14300036430358887
# Epoch [349/500]
# Step [1/1], Loss: 0.16828
# Time elasped: 0.14614439010620117
# Epoch [350/500]
# Step [1/1], Loss: 0.16160
# Time elasped: 0.14800071716308594
# Test set accuracy: 6.25%
# --------------------------
# Epoch [351/500]
# Step [1/1], Loss: 0.13851
# Time elasped: 0.14400076866149902
# Epoch [352/500]
# Step [1/1], Loss: 0.18002
# Time elasped: 0.13903045654296875
# Epoch [353/500]
# Step [1/1], Loss: 0.16834
# Time elasped: 0.14397120475769043
# Epoch [354/500]
# Step [1/1], Loss: 0.17542
# Time elasped: 0.14799761772155762
# Epoch [355/500]
# Step [1/1], Loss: 0.15977
# Time elasped: 0.14355969429016113
# Test set accuracy: 5.46875%
# --------------------------
# Epoch [356/500]
# Step [1/1], Loss: 0.15949
# Time elasped: 0.14400124549865723
# Epoch [357/500]
# Step [1/1], Loss: 0.18519
# Time elasped: 0.14198565483093262
# Epoch [358/500]
# Step [1/1], Loss: 0.14010
# Time elasped: 0.1439981460571289
# Epoch [359/500]
# Step [1/1], Loss: 0.15449
# Time elasped: 0.14400100708007812
# Epoch [360/500]
# Step [1/1], Loss: 0.14673
# Time elasped: 0.14499902725219727
# Test set accuracy: 4.6875%
# --------------------------
# Epoch [361/500]
# Step [1/1], Loss: 0.16507
# Time elasped: 0.14599990844726562
# Epoch [362/500]
# Step [1/1], Loss: 0.17012
# Time elasped: 0.14500021934509277
# Epoch [363/500]
# Step [1/1], Loss: 0.18103
# Time elasped: 0.14154481887817383
# Epoch [364/500]
# Step [1/1], Loss: 0.18265
# Time elasped: 0.14503026008605957
# Epoch [365/500]
# Step [1/1], Loss: 0.15653
# Time elasped: 0.14096975326538086
# Test set accuracy: 4.6875%
# --------------------------
# Epoch [366/500]
# Step [1/1], Loss: 0.17485
# Time elasped: 0.14627981185913086
# Epoch [367/500]
# Step [1/1], Loss: 0.13201
# Time elasped: 0.14551448822021484
# Epoch [368/500]
# Step [1/1], Loss: 0.14640
# Time elasped: 0.14496564865112305
# Epoch [369/500]
# Step [1/1], Loss: 0.17710
# Time elasped: 0.1440296173095703
# Epoch [370/500]
# Step [1/1], Loss: 0.15763
# Time elasped: 0.14300131797790527
# Test set accuracy: 5.46875%
# --------------------------
# Epoch [371/500]
# Step [1/1], Loss: 0.17321
# Time elasped: 0.1510016918182373
# Epoch [372/500]
# Step [1/1], Loss: 0.18604
# Time elasped: 0.1439986228942871
# Epoch [373/500]
# Step [1/1], Loss: 0.14462
# Time elasped: 0.1430373191833496
# Epoch [374/500]
# Step [1/1], Loss: 0.15259
# Time elasped: 0.14496278762817383
# Epoch [375/500]
# Step [1/1], Loss: 0.14889
# Time elasped: 0.1420290470123291
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [376/500]
# Step [1/1], Loss: 0.16871
# Time elasped: 0.14503002166748047
# Epoch [377/500]
# Step [1/1], Loss: 0.17917
# Time elasped: 0.14003372192382812
# Epoch [378/500]
# Step [1/1], Loss: 0.19137
# Time elasped: 0.14400577545166016
# Epoch [379/500]
# Step [1/1], Loss: 0.15583
# Time elasped: 0.14699888229370117
# Epoch [380/500]
# Step [1/1], Loss: 0.16004
# Time elasped: 0.14414429664611816
# Test set accuracy: 5.46875%
# --------------------------
# Epoch [381/500]
# Step [1/1], Loss: 0.16988
# Time elasped: 0.14754056930541992
# Epoch [382/500]
# Step [1/1], Loss: 0.19112
# Time elasped: 0.1399991512298584
# Epoch [383/500]
# Step [1/1], Loss: 0.20903
# Time elasped: 0.14703059196472168
# Epoch [384/500]
# Step [1/1], Loss: 0.15978
# Time elasped: 0.14400005340576172
# Epoch [385/500]
# Step [1/1], Loss: 0.16242
# Time elasped: 0.14497089385986328
# Test set accuracy: 6.25%
# --------------------------
# Epoch [386/500]
# Step [1/1], Loss: 0.18047
# Time elasped: 0.1463463306427002
# Epoch [387/500]
# Step [1/1], Loss: 0.14735
# Time elasped: 0.14499950408935547
# Epoch [388/500]
# Step [1/1], Loss: 0.17070
# Time elasped: 0.14203190803527832
# Epoch [389/500]
# Step [1/1], Loss: 0.17097
# Time elasped: 0.14500021934509277
# Epoch [390/500]
# Step [1/1], Loss: 0.17807
# Time elasped: 0.14299917221069336
# Test set accuracy: 4.6875%
# --------------------------
# Epoch [391/500]
# Step [1/1], Loss: 0.19732
# Time elasped: 0.14503049850463867
# Epoch [392/500]
# Step [1/1], Loss: 0.15102
# Time elasped: 0.14497041702270508
# Epoch [393/500]
# Step [1/1], Loss: 0.15857
# Time elasped: 0.1439990997314453
# Epoch [394/500]
# Step [1/1], Loss: 0.18889
# Time elasped: 0.14290857315063477
# Epoch [395/500]
# Step [1/1], Loss: 0.14970
# Time elasped: 0.13900256156921387
# Test set accuracy: 5.46875%
# --------------------------
# Epoch [396/500]
# Step [1/1], Loss: 0.12843
# Time elasped: 0.14800143241882324
# Epoch [397/500]
# Step [1/1], Loss: 0.17723
# Time elasped: 0.14499783515930176
# Epoch [398/500]
# Step [1/1], Loss: 0.17690
# Time elasped: 0.14700102806091309
# Epoch [399/500]
# Step [1/1], Loss: 0.15539
# Time elasped: 0.14599967002868652
# Epoch [400/500]
# Step [1/1], Loss: 0.17311
# Time elasped: 0.14260172843933105
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [401/500]
# Step [1/1], Loss: 0.17296
# Time elasped: 0.14100003242492676
# Epoch [402/500]
# Step [1/1], Loss: 0.17244
# Time elasped: 0.14300012588500977
# Epoch [403/500]
# Step [1/1], Loss: 0.17207
# Time elasped: 0.14902949333190918
# Epoch [404/500]
# Step [1/1], Loss: 0.17422
# Time elasped: 0.14999675750732422
# Epoch [405/500]
# Step [1/1], Loss: 0.14488
# Time elasped: 0.14939188957214355
# Test set accuracy: 4.6875%
# --------------------------
# Epoch [406/500]
# Step [1/1], Loss: 0.14196
# Time elasped: 0.15000009536743164
# Epoch [407/500]
# Step [1/1], Loss: 0.18598
# Time elasped: 0.1420269012451172
# Epoch [408/500]
# Step [1/1], Loss: 0.19426
# Time elasped: 0.14897370338439941
# Epoch [409/500]
# Step [1/1], Loss: 0.18499
# Time elasped: 0.14799833297729492
# Epoch [410/500]
# Step [1/1], Loss: 0.13277
# Time elasped: 0.1490004062652588
# Test set accuracy: 10.9375%
# --------------------------
# Epoch [411/500]
# Step [1/1], Loss: 0.18278
# Time elasped: 0.14499974250793457
# Epoch [412/500]
# Step [1/1], Loss: 0.17527
# Time elasped: 0.1432201862335205
# Epoch [413/500]
# Step [1/1], Loss: 0.18813
# Time elasped: 0.13997101783752441
# Epoch [414/500]
# Step [1/1], Loss: 0.14971
# Time elasped: 0.14400005340576172
# Epoch [415/500]
# Step [1/1], Loss: 0.16689
# Time elasped: 0.14600014686584473
# Test set accuracy: 8.59375%
# --------------------------
# Epoch [416/500]
# Step [1/1], Loss: 0.12921
# Time elasped: 0.14902210235595703
# Epoch [417/500]
# Step [1/1], Loss: 0.17358
# Time elasped: 0.14397811889648438
# Epoch [418/500]
# Step [1/1], Loss: 0.12766
# Time elasped: 0.14403247833251953
# Epoch [419/500]
# Step [1/1], Loss: 0.14291
# Time elasped: 0.14458084106445312
# Epoch [420/500]
# Step [1/1], Loss: 0.17104
# Time elasped: 0.14399504661560059
# Test set accuracy: 7.03125%
# --------------------------
# Epoch [421/500]
# Step [1/1], Loss: 0.18599
# Time elasped: 0.14400100708007812
# Epoch [422/500]
# Step [1/1], Loss: 0.16276
# Time elasped: 0.1439971923828125
# Epoch [423/500]
# Step [1/1], Loss: 0.17340
# Time elasped: 0.14445877075195312
# Epoch [424/500]
# Step [1/1], Loss: 0.16971
# Time elasped: 0.14302992820739746
# Epoch [425/500]
# Step [1/1], Loss: 0.16568
# Time elasped: 0.14397025108337402
# Test set accuracy: 3.90625%
# --------------------------
# Epoch [426/500]
# Step [1/1], Loss: 0.16081
# Time elasped: 0.14499998092651367
# Epoch [427/500]
# Step [1/1], Loss: 0.15819
# Time elasped: 0.1510002613067627
# Epoch [428/500]
# Step [1/1], Loss: 0.13488
# Time elasped: 0.14702844619750977
# Epoch [429/500]
# Step [1/1], Loss: 0.14024
# Time elasped: 0.1469714641571045
# Epoch [430/500]
# Step [1/1], Loss: 0.14733
# Time elasped: 0.14699983596801758
# Test set accuracy: 10.15625%
# --------------------------
# Epoch [431/500]
# Step [1/1], Loss: 0.17016
# Time elasped: 0.1480100154876709
# Epoch [432/500]
# Step [1/1], Loss: 0.13350
# Time elasped: 0.14299941062927246
# Epoch [433/500]
# Step [1/1], Loss: 0.16525
# Time elasped: 0.1450355052947998
# Epoch [434/500]
# Step [1/1], Loss: 0.19129
# Time elasped: 0.14496517181396484
# Epoch [435/500]
# Step [1/1], Loss: 0.18865
# Time elasped: 0.14500045776367188
# Test set accuracy: 9.375%
# --------------------------
# Epoch [436/500]
# Step [1/1], Loss: 0.16792
# Time elasped: 0.1640002727508545
# Epoch [437/500]
# Step [1/1], Loss: 0.19518
# Time elasped: 0.16559696197509766
# Epoch [438/500]
# Step [1/1], Loss: 0.22273
# Time elasped: 0.15302062034606934
# Epoch [439/500]
# Step [1/1], Loss: 0.16823
# Time elasped: 0.15298128128051758
# Epoch [440/500]
# Step [1/1], Loss: 0.20092
# Time elasped: 0.14699816703796387
# Test set accuracy: 7.03125%
# --------------------------
# Epoch [441/500]
# Step [1/1], Loss: 0.18051
# Time elasped: 0.149566650390625
# Epoch [442/500]
# Step [1/1], Loss: 0.15151
# Time elasped: 0.15000081062316895
# Epoch [443/500]
# Step [1/1], Loss: 0.14805
# Time elasped: 0.14699935913085938
# Epoch [444/500]
# Step [1/1], Loss: 0.14940
# Time elasped: 0.14502334594726562
# Epoch [445/500]
# Step [1/1], Loss: 0.14910
# Time elasped: 0.14497709274291992
# Test set accuracy: 4.6875%
# --------------------------
# Epoch [446/500]
# Step [1/1], Loss: 0.15061
# Time elasped: 0.14699959754943848
# Epoch [447/500]
# Step [1/1], Loss: 0.18535
# Time elasped: 0.14299941062927246
# Epoch [448/500]
# Step [1/1], Loss: 0.20533
# Time elasped: 0.1420295238494873
# Epoch [449/500]
# Step [1/1], Loss: 0.13902
# Time elasped: 0.1492481231689453
# Epoch [450/500]
# Step [1/1], Loss: 0.16996
# Time elasped: 0.14003825187683105
# Test set accuracy: 5.46875%
# --------------------------
# Epoch [451/500]
# Step [1/1], Loss: 0.15489
# Time elasped: 0.14600086212158203
# Epoch [452/500]
# Step [1/1], Loss: 0.16416
# Time elasped: 0.1420297622680664
# Epoch [453/500]
# Step [1/1], Loss: 0.18952
# Time elasped: 0.14096999168395996
# Epoch [454/500]
# Step [1/1], Loss: 0.16941
# Time elasped: 0.14600014686584473
# Epoch [455/500]
# Step [1/1], Loss: 0.18086
# Time elasped: 0.1425645351409912
# Test set accuracy: 9.375%
# --------------------------
# Epoch [456/500]
# Step [1/1], Loss: 0.15862
# Time elasped: 0.14499998092651367
# Epoch [457/500]
# Step [1/1], Loss: 0.15430
# Time elasped: 0.1430201530456543
# Epoch [458/500]
# Step [1/1], Loss: 0.14103
# Time elasped: 0.1420292854309082
# Epoch [459/500]
# Step [1/1], Loss: 0.13001
# Time elasped: 0.14099955558776855
# Epoch [460/500]
# Step [1/1], Loss: 0.14571
# Time elasped: 0.14355683326721191
# Test set accuracy: 6.25%
# --------------------------
# Epoch [461/500]
# Step [1/1], Loss: 0.17107
# Time elasped: 0.14400148391723633
# Epoch [462/500]
# Step [1/1], Loss: 0.17919
# Time elasped: 0.14299964904785156
# Epoch [463/500]
# Step [1/1], Loss: 0.16408
# Time elasped: 0.14100003242492676
# Epoch [464/500]
# Step [1/1], Loss: 0.17337
# Time elasped: 0.1490030288696289
# Epoch [465/500]
# Step [1/1], Loss: 0.17332
# Time elasped: 0.1480247974395752
# Test set accuracy: 7.03125%
# --------------------------
# Epoch [466/500]
# Step [1/1], Loss: 0.17197
# Time elasped: 0.1640021800994873
# Epoch [467/500]
# Step [1/1], Loss: 0.16765
# Time elasped: 0.15149259567260742
# Epoch [468/500]
# Step [1/1], Loss: 0.17565
# Time elasped: 0.16159772872924805
# Epoch [469/500]
# Step [1/1], Loss: 0.16967
# Time elasped: 0.14500188827514648
# Epoch [470/500]
# Step [1/1], Loss: 0.12389
# Time elasped: 0.14999961853027344
# Test set accuracy: 6.25%
# --------------------------
# Epoch [471/500]
# Step [1/1], Loss: 0.16221
# Time elasped: 0.16102981567382812
# Epoch [472/500]
# Step [1/1], Loss: 0.18429
# Time elasped: 0.14796972274780273
# Epoch [473/500]
# Step [1/1], Loss: 0.13196
# Time elasped: 0.14353704452514648
# Epoch [474/500]
# Step [1/1], Loss: 0.14889
# Time elasped: 0.14099955558776855
# Epoch [475/500]
# Step [1/1], Loss: 0.17780
# Time elasped: 0.14499998092651367
# Test set accuracy: 4.6875%
# --------------------------
# Epoch [476/500]
# Step [1/1], Loss: 0.16583
# Time elasped: 0.1419999599456787
# Epoch [477/500]
# Step [1/1], Loss: 0.15915
# Time elasped: 0.1436777114868164
# Epoch [478/500]
# Step [1/1], Loss: 0.18017
# Time elasped: 0.14275264739990234
# Epoch [479/500]
# Step [1/1], Loss: 0.14702
# Time elasped: 0.14100193977355957
# Epoch [480/500]
# Step [1/1], Loss: 0.15544
# Time elasped: 0.14096903800964355
# Test set accuracy: 10.9375%
# --------------------------
# Epoch [481/500]
# Step [1/1], Loss: 0.20326
# Time elasped: 0.14302992820739746
# Epoch [482/500]
# Step [1/1], Loss: 0.16925
# Time elasped: 0.14699983596801758
# Epoch [483/500]
# Step [1/1], Loss: 0.14180
# Time elasped: 0.14800095558166504
# Epoch [484/500]
# Step [1/1], Loss: 0.16872
# Time elasped: 0.14702987670898438
# Epoch [485/500]
# Step [1/1], Loss: 0.17236
# Time elasped: 0.14496946334838867
# Test set accuracy: 5.46875%
# --------------------------
# Epoch [486/500]
# Step [1/1], Loss: 0.17063
# Time elasped: 0.15101385116577148
# Epoch [487/500]
# Step [1/1], Loss: 0.15284
# Time elasped: 0.1459958553314209
# Epoch [488/500]
# Step [1/1], Loss: 0.18033
# Time elasped: 0.14300322532653809
# Epoch [489/500]
# Step [1/1], Loss: 0.20520
# Time elasped: 0.14899849891662598
# Epoch [490/500]
# Step [1/1], Loss: 0.17762
# Time elasped: 0.14502930641174316
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [491/500]
# Step [1/1], Loss: 0.20427
# Time elasped: 0.14400100708007812
# Epoch [492/500]
# Step [1/1], Loss: 0.15637
# Time elasped: 0.14358091354370117
# Epoch [493/500]
# Step [1/1], Loss: 0.17696
# Time elasped: 0.14600062370300293
# Epoch [494/500]
# Step [1/1], Loss: 0.13513
# Time elasped: 0.14302921295166016
# Epoch [495/500]
# Step [1/1], Loss: 0.19679
# Time elasped: 0.14496922492980957
# Test set accuracy: 7.8125%
# --------------------------
# Epoch [496/500]
# Step [1/1], Loss: 0.13362
# Time elasped: 0.14532089233398438
# Epoch [497/500]
# Step [1/1], Loss: 0.18823
# Time elasped: 0.14399933815002441
# Epoch [498/500]
# Step [1/1], Loss: 0.17888
# Time elasped: 0.14600038528442383
# Epoch [499/500]
# Step [1/1], Loss: 0.18410
# Time elasped: 0.14400005340576172
# Epoch [500/500]
# Step [1/1], Loss: 0.18861
# Time elasped: 0.14400243759155273
# Test set accuracy: 11.71875%
# --------------------------
